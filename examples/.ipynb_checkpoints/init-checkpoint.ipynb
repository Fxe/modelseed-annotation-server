# %%
import logging
import os
import pymongo
import cobrakbase
import time
# %run ../../scripts/bios_utils.py
# %run ../../annotation-server/annotation_api_neo4j.py

# %%
# %run ../../annotation-server/annotation_api_neo4j.py
from neo4j import GraphDatabase
driver = GraphDatabase.driver("bolt://127.0.0.1:7687", auth=("neo4j", "123585"))
annotation_api = AnnotationApiNeo4j(driver)
#neo_annotation_api.init_constraints()

# %%
substem_ref = read_json('../../../data/tnseq/patric_subsystems/substem_ref.json')

# %%
# %%time
for doc in substem_ref['response']['docs']:
    value = doc['subsystem_name']
    
    ss_node = None
    
    with driver.session() as session:
        ss_node = session.write_transaction(add_value_node, 'FunctionGroup', value)
    
    if 'role_name' in doc:
        for role in doc['role_name']:
            role = role.strip()
            if len(role) > 0:
                with driver.session() as session:
                    function_node = session.write_transaction(add_value_node, 'Function', role)
                    session.write_transaction(add_relationship, 
                                    ss_node, function_node, 'has_function')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>()
#
# NameError: name 'driver' is not defined

# %%
modelseed_local = cobrakbase.modelseed.from_local('../../../ModelSEEDDatabase')
# Out:
# load: ../../../ModelSEEDDatabase/Biochemistry/reactions.tsv
# load: ../../../ModelSEEDDatabase/Biochemistry/compounds.tsv
# load: ../../../ModelSEEDDatabase/Biochemistry/Structures/Unique_ModelSEED_Structures.txt
# load: ../../../ModelSEEDDatabase/Biochemistry/Aliases/Unique_ModelSEED_Compound_Aliases.txt
# load: ../../../ModelSEEDDatabase/Biochemistry/Aliases/Unique_ModelSEED_Reaction_Aliases.txt
# load: ../../../ModelSEEDDatabase/Biochemistry/Aliases/Unique_ModelSEED_Reaction_ECs.txt

# %%
node = annotation_api.get_node('RefSeqGenome', 'GCF_000007025.1')
print(node)
# Out:
# <Node id=57 labels={'RefSeqGenome'} properties={'genetic_code': 11, 'notes': '', 'release': '1', 'created_at': 1563767041245, 'scientific_name': 'Rickettsia conorii str. Malish 7', 'source': 'refseq', 'taxonomy': 'cellular organisms; Bacteria; Proteobacteria; Alphaproteobacteria; Rickettsiales; Rickettsiaceae; Rickettsieae; Rickettsia; spotted fever group; Rickettsia conorii', 'type': 'Representative', 'external_source_origination_date': '16-NOV-2016', 'count_features': 1532, 'workspace_id': 'jplfaria:narrative_1524466549180', 'dna_size': 1268755, 'original_source_file_name': 'GCF_000007025.1_ASM702v1_genomic.gbff', 'reference_annotation': 0, 'updated_at': 1563767041245, 'num_contigs': 1, 'assembly_ref': '19217/46804/1', 'domain': 'Bacteria', 'source_id': 'NC_003103', 'id': 'GCF_000007025.1', 'taxon_ref': '12570/666753/1', 'genbank_handle_ref': 'KBH_235629', 'gc_content': 0.3243880812292365, 'key': 'GCF_000007025.1'}>

# %%
rxn.data
# Out:
# {'id': 'rxn00001',
#  'abbreviation': 'R00004',
#  'name': 'diphosphate phosphohydrolase',
#  'code': '(1) cpd00001[0] + (1) cpd00012[0] <=> (2) cpd00009[0]',
#  'stoichiometry': '-1:cpd00001:0:0:"H2O";-1:cpd00012:0:0:"PPi";2:cpd00009:0:0:"Phosphate";1:cpd00067:0:0:"H+"',
#  'is_transport': 0,
#  'equation': '(1) cpd00001[0] + (1) cpd00012[0] <=> (2) cpd00009[0] + (1) cpd00067[0]',
#  'definition': '(1) H2O[0] + (1) PPi[0] <=> (2) Phosphate[0] + (1) H+[0]',
#  'reversibility': '>',
#  'direction': '=',
#  'abstract_reaction': nan,
#  'pathways': 'MetaCyc: Degradation (Degradation/Utilization/Assimilation); Glyphosate-Degradation (glyphosate degradation); Noncarbon-Nutrients (Inorganic Nutrient Metabolism); PWY-7805 ((aminomethyl)phosphonate degradation); PWY-7807 (glyphosate degradation III); Phosphorus-Compounds (Phosphorus Compound Metabolism)',
#  'aliases': 'AraCyc: INORGPYROPHOSPHAT-RXN|BiGG: IPP1; PPA; PPA_1; PPAm|BrachyCyc: INORGPYROPHOSPHAT-RXN|KEGG: R00004|MetaCyc: INORGPYROPHOSPHAT-RXN|Name: Diphosphate phosphohydrolase; Inorganic diphosphatase; Inorganic pyrophosphatase; Pyrophosphate phosphohydrolase; diphosphate phosphohydrolase; inorganic diphosphatase; inorganic diphosphatase (one proton translocation); inorganicdiphosphatase; pyrophosphate phosphohydrolase',
#  'ec_numbers': '3.6.1.1',
#  'deltag': -3.46,
#  'deltagerr': 0.05,
#  'compound_ids': 'cpd00001;cpd00009;cpd00012;cpd00067',
#  'status': 'OK',
#  'is_obsolete': 0,
#  'linked_reaction': 'rxn27946;rxn27947;rxn27948;rxn32487;rxn38157;rxn38158',
#  'notes': 'GFC|HB|EQC|EQU',
#  'source': 'Primary Database',
#  'key': 'id'}

# %%
props_str = to_str_dict(props)
props_str
# Out:
# '{name:"a \\"banana\\"", key:"banana"}'

# %%
props = {
    'name' : 'a "banana"'
}
add_node(annotation_api, 'Fruit', 'banana', props)
# Out:
# <Node id=97399 labels={'Fruit'} properties={'name': 'a "banana"', 'created_at': 1568612758221, 'updated_at': 1568612758221, 'key': 'banana'}>

# %%
props
# Out:
# {'id': 'rxn10881',
#  'name': 'streptomycin 3"-adenylyltransferase',
#  'equation': '(1) cpd00002[0] + (1) cpd00067[0] + (1) cpd00328[0] <= (1) cpd00012[0] + (1) cpd16061[0]',
#  'definition': '(1) ATP[0] + (1) H+[0] + (1) Streptomycin[0] <= (1) PPi[0] + (1) 3"-Adenylylstreptomycin[0]',
#  'key': 'rxn10881'}

# %%
# Out:
# abstract_reaction
# pathways
# ec_numbers
# linked_reaction

# %% [markdown]
# # Load ModelSEED Reactions

# %%
for seed_id in modelseed_local.reactions:
    rxn = modelseed_local.get_seed_reaction(seed_id)
    rxn_node = annotation_api.get_node('ModelSeedReaction', seed_id)
    if rxn_node == None:
        delete = set()
        for k in rxn.data:
            if pd.isna(rxn.data[k]):
                delete.add(k)
        for k in delete:
            del rxn.data[k]
        annotation_api.add_node('ModelSeedReaction', seed_id, rxn.data)

# %% [markdown]
# # Load KEGG Orthologs

# %%
df_kegg_ko = pd.read_csv('../../data/ko_kegg.tsv', sep='\t')
for row_id, d in df_kegg_ko.iterrows():
    kegg_ko = d['kegg_ko']
    kegg_rxns = d['kegg_rxns']
    
    ko_node = annotation_api.get_node('KeggOrthology', kegg_ko)
    if ko_node == None:
        annotation_api.add_node('KeggOrthology', kegg_ko, {})
        ko_node = annotation_api.get_node('KeggOrthology', kegg_ko)
        
    if not pd.isna(kegg_rxns):
        for rxn_id in kegg_rxns.split(';'):
            rxn_node = annotation_api.get_node('LigandReaction', seed_id)
            if rxn_node == None:
                annotation_api.add_node('LigandReaction', rxn_id, {})
                rxn_node = annotation_api.get_node('LigandReaction', rxn_id)
            annotation_api.link_nodes(ko_node, rxn_node, 'has_reaction')

# %% [markdown]
# # Load KEGG Orthologs to SEED

# %%
for seed_id in modelseed_local.reactions:
    rxn = modelseed_local.get_seed_reaction(seed_id)
    seed_rxn_node = annotation_api.get_node('ModelSeedReaction', seed_id)
    if seed_id in modelseed_local.reaction_aliases and 'KEGG' in modelseed_local.reaction_aliases[seed_id]:
        for kegg_id in modelseed_local.reaction_aliases[seed_id]['KEGG']:
            kegg_rxn_node = annotation_api.get_node('LigandReaction', kegg_id)
            if not kegg_rxn_node == None and not seed_rxn_node == None:
                annotation_api.link_nodes(seed_rxn_node, kegg_rxn_node, 'has_crossreference_to')

# %% [markdown]
# # Load Templates

# %%
kbase = cobrakbase.KBaseAPI(token='YAFOCRSMRNDXZ7KMW7GCK5AC3SBNTEFD')
templates = {}
templates['GramNegModelTemplateV2'] = kbase.get_object('GramNegModelTemplateV2', 'NewKBaseModelTemplates')
templates['GramNegModelTemplate'] = kbase.get_object('GramNegModelTemplate', 'NewKBaseModelTemplates')
#template_doc = annotation_api.add_template('GramNegModelTemplateV2', templates['GramNegModelTemplateV2'])
#template_doc = annotation_api.add_template('GramNegModelTemplate', templates['GramNegModelTemplate'])

# %% [raw]
# def add_template(self, template_id, template):
#         roles = {}
#         function_uids = {}
#         compcompound_compartment = {}
#
#         for compcompound in template['compcompounds']:
#             compcompound_compartment[compcompound['id']] = compcompound['templatecompartment_ref'].split('/')[-1]
#
#         for role in template['roles']:
#             roles[role['id']] = role['name']
#         for role_id in roles:
#             function = roles[role_id]
#             #print(function)
#             function_doc = self.get_function(function)
#             if function_doc['value'] == function:
#                 function_uids[function] = function_doc['_id']
#             else:
#                 print('errooo!')
#         missing_function = set()
#         for role_id in roles:
#             function = roles[role_id]
#             if not function in function_uids:
#                 missing_function.add(function)
#
#         print(len(missing_function))
#
#         cpx_to_function_uids = {}
#         for cpx in template['complexes']:
#             uids = set()
#             for complexrole in cpx['complexroles']:
#                 role_id = complexrole['templaterole_ref'].split('/')[-1]
#                 if role_id in roles:
#                     uids.add(function_uids[roles[role_id]])
#                 else:
#                     print('errooo!')
#
#             cpx_to_function_uids[cpx['id']] = uids
#
#         reactions = {}
#         for rxn in template['reactions']:
#             rxn_id = rxn['reaction_ref'].split('/')[-1]
#             rxn_compartments = set()
#             for templateReactionReagent in rxn['templateReactionReagents']:
#                 templatecompcompound_ref = templateReactionReagent['templatecompcompound_ref'].split('/')[-1]
#                 rxn_compartments.add(compcompound_compartment[templatecompcompound_ref])
#             or_rule = set()
#             for complex_ref in rxn['templatecomplex_refs']:
#                 complex_id = complex_ref.split('/')[-1]
#                 and_rule = set()
#                 if complex_id in cpx_to_function_uids:
#                     and_rule = frozenset(cpx_to_function_uids[complex_id])
#                 or_rule.add(and_rule)
#
#             reactions[rxn_id] = {
#                 'functions' : list(map(lambda x : list(x), or_rule)),
#                 'compartment' : list(rxn_compartments),
#                 'base_cost' : rxn['base_cost'],
#                 'direction' : rxn['direction'],
#                 'forward_penalty' : rxn['forward_penalty'],
#                 'reverse_penalty' : rxn['reverse_penalty'],
#                 'type' : rxn['type'],
#                 'GapfillDirection' : rxn['GapfillDirection'],
#
#             }
#
#         template_doc = {
#             '_id' : template_id,
#             'reactions' : reactions
#         }
#
#         self.collection_templates.insert_one(template_doc)
#
#         return template_doc

# %%
template_node = annotation_api.get_node('TemplateSet', template_id)
if template_node == None:
    annotation_api.add_node('TemplateSet', template_id, {})
    template_node = annotation_api.get_node('TemplateSet', template_id)
template_node
# Out:
# <Node id=172061 labels={'TemplateSet'} properties={'updated_at': 1568620759396, 'created_at': 1568620759396, 'key': 'GramNegModelTemplate'}>

# %%
#def add_template(annotation_api, template_id, template):
template_id = 'GramNegModelTemplate'
template = templates['GramNegModelTemplate']
roles = {}
function_uids = {}
function_complexes = {}
compcompound_compartment = {}

for compcompound in template['compcompounds']:
    compcompound_compartment[compcompound['id']] = compcompound['templatecompartment_ref'].split('/')[-1]

for role in template['roles']:
    roles[role['id']] = role['name']
for role_id in roles:
    function = roles[role_id]
    function_data = annotation_api.get_function(function)
    if not function_data == None and function_data.get('key') == function:
        function_uids[function] = function_data
    else:
        #print('errooo!')
        pass

# %%
missing_function = set()
found_function = set()
for role_id in roles:
    function = roles[role_id]
    if not function in function_uids:
        missing_function.add(function)
    else:
        found_function.add(function)
        
logger.warning('%d %d', len(found_function), len(missing_function))

for f in missing_function:
    annotation_api.add_node('Function', f, {})

cpx_to_function_uids = {}
for cpx in template['complexes']:
    uids = set()
    for complexrole in cpx['complexroles']:
        role_id = complexrole['templaterole_ref'].split('/')[-1]
        if role_id in roles:
            uids.add(function_uids[roles[role_id]])
        else:
            print('errooo!')
    cpx_to_function_uids[cpx['id']] = uids
#add_template(annotation_api, 'GramNegModelTemplate', templates['GramNegModelTemplate'])
# Out:
# WARNING:__main__:19936 0

# %%
for cpx_id in cpx_to_function_uids:
    if len(cpx_to_function_uids[cpx_id]) > 1:
        complex_node = annotation_api.get_node('FunctionComplex', cpx_id)
        if complex_node == None:
            complex_node = annotation_api.add_node('FunctionComplex', cpx_id)
            for n in cpx_to_function_uids[cpx_id]:
                annotation_api.link_nodes(complex_node, n, 'has_function')
            function_complexes[cpx_id] = complex_node

# %%
rxn
# Out:
# {'GapfillDirection': '=',
#  'base_cost': 4,
#  'direction': '=',
#  'forward_penalty': 0,
#  'id': 'rxn00594_c',
#  'maxforflux': 100,
#  'maxrevflux': -100,
#  'name': 'Anthranilate,NADH:oxygen oxidoreductase (1,2-hydroxylating, deaminating, decarboxylating)',
#  'reverse_penalty': -8.22197,
#  'templateReactionReagents': [{'coefficient': -1,
#    'templatecompcompound_ref': '~/compcompounds/id/cpd00004_c'},
#   {'coefficient': -1,
#    'templatecompcompound_ref': '~/compcompounds/id/cpd00007_c'},
#   {'coefficient': -3,
#    'templatecompcompound_ref': '~/compcompounds/id/cpd00067_c'},
#   {'coefficient': -1,
#    'templatecompcompound_ref': '~/compcompounds/id/cpd00093_c'},
#   {'coefficient': 1,
#    'templatecompcompound_ref': '~/compcompounds/id/cpd00003_c'},
#   {'coefficient': 1,
#    'templatecompcompound_ref': '~/compcompounds/id/cpd00011_c'},
#   {'coefficient': 1,
#    'templatecompcompound_ref': '~/compcompounds/id/cpd00013_c'},
#   {'coefficient': 1,
#    'templatecompcompound_ref': '~/compcompounds/id/cpd00077_c'}],
#  'templatecompartment_ref': '~/compartments/id/c',
#  'templatecomplex_refs': ['~/complexes/id/cpx30659'],
#  'type': 'conditional'}

# %%
reactions = {}
for rxn in template['reactions']:
    rxn_id = rxn['id']
    if '_' in rxn_id:
        rxn_id = rxn_id.split('_')[0]
    
    rxn_node = annotation_api.get_node('ModelSeedReaction', rxn_id)
    if not rxn_node == None:
        #print(rxn_node)
    #rxn_id = rxn['reaction_ref'].split('/')[-1]
        rxn_compartments = set()
        for templateReactionReagent in rxn['templateReactionReagents']:
            templatecompcompound_ref = templateReactionReagent['templatecompcompound_ref'].split('/')[-1]
            rxn_compartments.add(compcompound_compartment[templatecompcompound_ref])



        or_rule = set()
        for complex_ref in rxn['templatecomplex_refs']:
            complex_id = complex_ref.split('/')[-1]
            if complex_id in cpx_to_function_uids:
                if len(cpx_to_function_uids[complex_id]) > 1:
                    or_rule.add(function_complexes[complex_id])
                else:
                    or_rule.add(list(cpx_to_function_uids[complex_id])[0])

        #print(rxn['id'], rxn_compartments, or_rule)

        props = {
            'compartment' : ';'.join(sorted(list(rxn_compartments))),
            'reaction' : rxn.get('key'),
            'base_cost' : rxn['base_cost'],
            'direction' : rxn['direction'],
            'forward_penalty' : rxn['forward_penalty'],
            'reverse_penalty' : rxn['reverse_penalty'],
            'type' : rxn['type'],
            'GapfillDirection' : rxn['GapfillDirection'],
        }

        add_template_reaction_annotation(annotation_api, template_node, rxn_node, rxn_compartments, or_rule, props)
# Out:
# <Node id=87709 labels={'ModelSeedReaction'} properties={'updated_at': 1568609822298, 'equation': '(1) cpd00004[0] + (1) cpd00007[0] + (3) cpd00067[0] + (1) cpd00093[0] => (1) cpd00003[0] + (1) cpd00011[0] + (1) cpd00013[0] + (1) cpd00077[0]', 'name': 'Anthranilate,NADH:oxygen oxidoreductase (1,2-hydroxylating, deaminating, decarboxylating)', 'created_at': 1568609822298, 'definition': '(1) NADH[0] + (1) O2[0] + (3) H+[0] + (1) Anthranilate[0] => (1) NAD[0] + (1) CO2[0] + (1) NH3[0] + (1) Catechol[0]', 'id': 'rxn00594', 'key': 'rxn00594'}>
# rxn00594_c {'c'} {<Node id=164627 labels={'Function'} properties={'updated_at': 1568619784117, 'created_at': 1568619784117, 'key': 'toluene dioxygenase (EC 1.14.12.11)'}>}
# <Node id=88191 labels={'ModelSeedReaction'} properties={'updated_at': 1568609828596, 'equation': '(1) cpd00002[0] + (1) cpd00167[0] <=> (1) cpd00008[0] + (1) cpd00067[0] + (1) cpd01899[0]', 'name': 'ATP:ceramide 1-phosphotransferase', 'created_at': 1568609828596, 'definition': '(1) ATP[0] + (1) Ceramide[0] <=> (1) ADP[0] + (1) H+[0] + (1) Ceramide phosphate[0]', 'id': 'rxn01087', 'key': 'rxn01087'}>
# rxn01087_c {'c'} {<Node id=172378 labels={'Function'} properties={'updated_at': 1568619882089, 'created_at': 1568619882089, 'key': 'ceramide kinase (EC 2.7.1.138)'}>}
# <Node id=90321 labels={'ModelSeedReaction'} properties={'updated_at': 1568609856653, 'equation': '(1) cpd00001[0] + (1) cpd03106[0] <=> (1) cpd00013[0] + (1) cpd03703[0]', 'name': '4-aminoimidazole aminohydrolase', 'created_at': 1568609856653, 'definition': '(1) H2O[0] + (1) Aminoimidazole[0] <=> (1) NH3[0] + (1) Imidazolone[0]', 'id': 'rxn03234', 'key': 'rxn03234'}>
# rxn03234_c {'c'} {<Node id=164649 labels={'Function'} properties={'updated_at': 1568619784368, 'created_at': 1568619784368, 'key': 'aminoimidazolase (EC 3.5.4.8)'}>}
# <Node id=88826 labels={'ModelSeedReaction'} properties={'updated_at': 1568609837045, 'equation': '(1) cpd00078[0] + (1) cpd00380[0] <=> (1) cpd00036[0] + (1) cpd00416[0]', 'name': 'Succinyl-CoA:citramalate CoA-transferase', 'created_at': 1568609837045, 'definition': '(1) Succinyl-CoA[0] + (1) Itaconate[0] <=> (1) Succinate[0] + (1) Itaconyl-CoA[0]', 'id': 'rxn01734', 'key': 'rxn01734'}>
# rxn01734_c {'c'} {<Node id=165743 labels={'Function'} properties={'updated_at': 1568619797212, 'created_at': 1568619797212, 'key': 'arsenate-mycothiol transferase (EC 2.8.4.2)'}>}
# <Node id=89365 labels={'ModelSeedReaction'} properties={'updated_at': 1568609843917, 'equation': '(1) cpd00001[0] + (1) cpd02154[0] <=> (1) cpd00013[0] + (1) cpd00769[0]', 'name': 'N-Formimino-L-aspartate iminohydrolase', 'created_at': 1568609843917, 'definition': '(1) H2O[0] + (1) N-Formimino-L-aspartate[0] <=> (1) NH3[0] + (1) N-Formyl-L-aspartate[0]', 'id': 'rxn02282', 'key': 'rxn02282'}>
# rxn02282_c {'c'} {<Node id=170592 labels={'Function'} properties={'updated_at': 1568619858554, 'created_at': 1568619858554, 'key': 'allantoate deiminase (EC 3.5.3.9)'}>}
# <Node id=97086 labels={'ModelSeedReaction'} properties={'updated_at': 1568609947469, 'equation': '(1) cpd00010[0] + (1) cpd00278[0] + (2) cpd15876[0] => (1) cpd00011[0] + (1) cpd00067[0] + (1) cpd11175[0] + (2) cpd15877[0]', 'name': 'indolepyruvate ferredoxin oxidoreductase', 'created_at': 1568609947469, 'definition': '(1) CoA[0] + (1) Indolepyruvate[0] + (2) ferredoxin (oxidized) 2[4Fe-4S][0] => (1) CO2[0] + (1) H+[0] + (1) S-2-(Indol-3-yl)acetyl-CoA[0] + (2) ferredoxin (reduced) 2[4Fe-4S][0]', 'id': 'rxn10561', 'key': 'rxn10561'}>
# rxn10561_c {'c'} set()
# <Node id=89284 labels={'ModelSeedReaction'} properties={'updated_at': 1568609842909, 'equation': '(1) cpd00443[0] + (1) cpd02920[0] => (1) cpd00012[0] + (1) cpd00683[0]', 'name': '2-amino-4-hydroxy-6-hydroxymethyl-7,8-dihydropteridine-diphosphate:4-aminobenzoate 2-amino-4-hydroxydihydropteridine-6-methenyltransferase', 'created_at': 1568609842909, 'definition': '(1) ABEE[0] + (1) 2-Amino-4-hydroxy-6-hydroxymethyl-7-8-dihydropteridinediphosphate[0] => (1) PPi[0] + (1) Dihydropteroate[0]', 'id': 'rxn02201', 'key': 'rxn02201'}>
# rxn02201_c {'c'} {<Node id=75725 labels={'Function'} properties={'updated_at': 1563778372546, 'created_at': 1563774189888, 'key': 'Dihydropteroate synthase (EC 2.5.1.15)'}>, <Node id=77558 labels={'Function'} properties={'updated_at': 1563774404730, 'created_at': 1563774404730, 'key': '3-phosphoshikimate 1-carboxyvinyltransferase (EC 2.5.1.19)'}>}
# <Node id=89324 labels={'ModelSeedReaction'} properties={'updated_at': 1568609843400, 'equation': '(1) cpd00007[0] + (1) cpd00024[0] + (1) cpd00717[0] => (1) cpd00001[0] + (1) cpd00011[0] + (1) cpd00036[0] + (1) cpd00067[0] + (1) cpd01071[0]', 'name': 'dihydroflavonol,2-oxoglutarate:oxygen oxidoreductase', 'created_at': 1568609843400, 'definition': '(1) O2[0] + (1) 2-Oxoglutarate[0] + (1) Aromadendrin[0] => (1) H2O[0] + (1) CO2[0] + (1) Succinate[0] + (1) H+[0] + (1) Luteolin[0]', 'id': 'rxn02241', 'key': 'rxn02241'}>
# rxn02241_c {'c'} {<Node id=171887 labels={'Function'} properties={'updated_at': 1568619875861, 'created_at': 1568619875861, 'key': 'mugineic-acid 3-dioxygenase (EC 1.14.11.25)'}>}
# <Node id=96178 labels={'ModelSeedReaction'} properties={'updated_at': 1568609934757, 'equation': '(6) cpd00001[0] + (6) cpd00003[0] + (5) cpd00007[0] + (6) cpd00010[0] + (1) cpd15295[0] => (6) cpd00004[0] + (7) cpd00022[0] + (5) cpd00025[0] + (7) cpd00067[0]', 'name': 'Fatty acid oxidation', 'created_at': 1568609934757, 'definition': '(6) H2O[0] + (6) NAD[0] + (5) O2[0] + (6) CoA[0] + (1) Tetradecenoyl-CoA[0] => (6) NADH[0] + (7) Acetyl-CoA[0] + (5) H2O2[0] + (7) H+[0]', 'id': 'rxn09471', 'key': 'rxn09471'}>
# rxn09471_c {'c'} set()
# <Node id=92732 labels={'ModelSeedReaction'} properties={'updated_at': 1568609888781, 'equation': '(1) cpd00067[1] + (1) cpd00187[1] <=> (1) cpd00067[0] + (1) cpd00187[0]', 'name': 'Monomethylamine symport', 'created_at': 1568609888781, 'definition': '(1) H+[1] + (1) Methanamine[1] <=> (1) H+[0] + (1) Methanamine[0]', 'id': 'rxn05704', 'key': 'rxn05704'}>
# rxn05704_c {'e', 'c'} set()
# <Node id=87468 labels={'ModelSeedReaction'} properties={'updated_at': 1568609818987, 'equation': '(1) cpd00002[0] + (1) cpd00033[0] + (1) cpd00506[0] => (1) cpd00008[0] + (1) cpd00009[0] + (1) cpd00042[0] + (1) cpd00067[0]', 'name': 'gamma-L-glutamyl-L-cysteine:glycine ligase (ADP-forming)', 'created_at': 1568609818987, 'definition': '(1) ATP[0] + (1) Glycine[0] + (1) gamma-Glutamylcysteine[0] => (1) ADP[0] + (1) Phosphate[0] + (1) GSH[0] + (1) H+[0]', 'id': 'rxn00351', 'key': 'rxn00351'}>
# rxn00351_c {'c'} {<Node id=82961 labels={'Function'} properties={'updated_at': 1563774527631, 'created_at': 1563774527631, 'key': 'Glutathione biosynthesis bifunctional protein gshF (EC 6.3.2.2)(EC 6.3.2.3)'}>, <Node id=82962 labels={'Function'} properties={'updated_at': 1563774527668, 'created_at': 1563774527668, 'key': 'Predicted alternative glutathione synthetase (EC 6.3.2.3)'}>, <Node id=168373 labels={'Function'} properties={'updated_at': 1568619830944, 'created_at': 1568619830944, 'key': 'tetrahydrosarcinapterin synthase (EC 6.3.2.33)'}>, <Node id=78857 labels={'Function'} properties={'updated_at': 1563774527650, 'created_at': 1563774431317, 'key': 'Glutathione synthetase (EC 6.3.2.3)'}>}
# <Node id=89737 labels={'ModelSeedReaction'} properties={'updated_at': 1568609848649, 'equation': '(1) cpd00006[0] + (1) cpd01823[0] <=> (1) cpd00005[0] + (1) cpd00067[0] + (1) cpd01235[0]', 'name': 'chlordecone-alcohol:NADP+ 2-oxidoreductase', 'created_at': 1568609848649, 'definition': '(1) NADP[0] + (1) Chlordecone alcohol[0] <=> (1) NADPH[0] + (1) H+[0] + (1) Kepone[0]', 'id': 'rxn02637', 'key': 'rxn02637'}>
# rxn02637_c {'c'} {<Node id=160658 labels={'Function'} properties={'updated_at': 1568619735874, 'created_at': 1568619735874, 'key': 'chlordecone reductase (EC 1.1.1.225)'}>}
# <Node id=92522 labels={'ModelSeedReaction'} properties={'updated_at': 1568609946549, 'equation': '(1) cpd00425[0] + (1) cpd02246[0] <= (1) cpd02438[0] + (1) cpd15895[0]', 'name': 'Dimethylamine methyltransferase', 'created_at': 1568609946549, 'definition': '(1) (CH3)2NH[0] + (1) CoM[0] <= (1) Methyl CoM[0] + (1) monomethylamine[0]', 'id': 'rxn10496', 'key': 'rxn10496'}>
# rxn10496_c {'c'} set()
# <Node id=93004 labels={'ModelSeedReaction'} properties={'updated_at': 1568609892477, 'equation': '(1) cpd00003[0] + (1) cpd11628[0] <= (1) cpd00004[0] + (1) cpd00067[0] + (1) cpd11728[0]', 'name': 'acyl-[acyl-carrier-protein]:NAD+ oxidoreductase', 'created_at': 1568609892477, 'definition': '(1) NAD[0] + (1) Acyl-[acyl-carrier protein][0] <= (1) NADH[0] + (1) H+[0] + (1) trans-2,3-Dehydroacyl-[acyl-carrier protein][0]', 'id': 'rxn05994', 'key': 'rxn05994'}>
# rxn05994_c {'c'} {<Node id=167488 labels={'Function'} properties={'updated_at': 1568619819447, 'created_at': 1568619819447, 'key': 'enoyl-[acyl-carrier-protein] reductase (NADH) (EC 1.3.1.9)'}>}
# <Node id=94354 labels={'ModelSeedReaction'} properties={'updated_at': 1568609910642, 'equation': '(1) cpd00213[0] + (1) cpd14700[0] <=> (1) cpd00056[0] + (1) cpd02700[0]', 'name': 'R07600', 'created_at': 1568609910642, 'definition': '(1) Lipoamide[0] + (1) 2-Methyl-1-hydroxypropyl-TPP[0] <=> (1) TPP[0] + (1) S-(2-Methylpropionyl)-dihydrolipoamide[0]', 'id': 'rxn07431', 'key': 'rxn07431'}>
# rxn07431_c {'c'} {<Node id=177491 labels={'FunctionComplex'} properties={'updated_at': 1568634678538, 'created_at': 1568634678538, 'key': 'cpx00466'}>, <Node id=170917 labels={'Function'} properties={'updated_at': 1568619862640, 'created_at': 1568619862640, 'key': 'pyruvate synthase (EC 1.2.7.1)'}>}
# <Node id=98030 labels={'ModelSeedReaction'} properties={'stoichiometry': '-1:cpd00003:0:0:"NAD";-1:cpd16404:0:0:"1-Hydroxyhexane-1,2,6-tricarboxylate";1:cpd00004:0:0:"NADH";1:cpd00011:0:0:"CO2";1:cpd16398:0:0:"2-Oxosuberate"', 'aliases': 'KEGG: R08215|MetaCyc: R218-RXN|Name: 1-Hydroxyhexane-1,2,6-tricarboxylate:NAD+ oxidoreductase; 1-Hydroxyhexane-1,2,6-tricarboxylate:NAD+ oxidoreductase (decarboxylating)', 'notes': 'GFP|EQP', 'code': '(1) cpd00003[0] + (1) cpd16404[0] <=> (1) cpd00004[0] + (1) cpd00011[0] + (1) cpd16398[0]', 'equation': '(1) cpd00003[0] + (1) cpd16404[0] => (1) cpd00004[0] + (1) cpd00011[0] + (1) cpd16398[0]', 'deltag': 10000000.0, 'is_transport': 0, 'created_at': 1568612911917, 'pathways': 'MetaCyc: Cofactor-Biosynthesis (Cofactor, Prosthetic Group, Electron Carrier, and Vitamin Biosynthesis); P241-PWY (coenzyme B biosynthesis)|KEGG: rn00680 (Methane metabolism); rn01210 (2-Oxocarboxylic acid metabolism)', 'ec_numbers': '1.1.1.-', 'source': 'Primary Database', 'abbreviation': 'R08215', 'is_obsolete': 0, 'compound_ids': 'cpd00003;cpd00004;cpd00011;cpd16398;cpd16404', 'updated_at': 1568612911917, 'reversibility': '?', 'name': '1-Hydroxyhexane-1,2,6-tricarboxylate:NAD+ oxidoreductase (decarboxylating)', 'deltagerr': 10000000.0, 'definition': '(1) NAD[0] + (1) 1-Hydroxyhexane-1,2,6-tricarboxylate[0] => (1) NADH[0] + (1) CO2[0] + (1) 2-Oxosuberate[0]', 'id': 'rxn11746', 'key': 'rxn11746', 'status': 'OK', 'direction': '>'}>
# rxn11746_c {'c'} set()
# <Node id=87943 labels={'ModelSeedReaction'} properties={'updated_at': 1568609825359, 'equation': '(1) cpd00012[0] + (1) cpd00067[0] + (1) cpd00114[0] <= (1) cpd00103[0] + (1) cpd00226[0]', 'name': 'IMP:diphosphate phospho-D-ribosyltransferase', 'created_at': 1568609825359, 'definition': '(1) PPi[0] + (1) H+[0] + (1) IMP[0] <= (1) PRPP[0] + (1) HYXN[0]', 'id': 'rxn00836', 'key': 'rxn00836'}>
# rxn00836_c {'c'} {<Node id=75577 labels={'Function'} properties={'updated_at': 1563778360269, 'created_at': 1563774186594, 'key': 'Hypoxanthine-guanine phosphoribosyltransferase (EC 2.4.2.8)'}>, <Node id=168692 labels={'Function'} properties={'updated_at': 1568619834933, 'created_at': 1568619834933, 'key': 'neolactotetraosylceramide alpha-2,3-sialyltransferase (EC 2.4.99.10)'}>}
# <Node id=90881 labels={'ModelSeedReaction'} properties={'updated_at': 1568609864777, 'equation': '(1) cpd02113[0] <=> (1) cpd02177[0]', 'name': 'R05516', 'created_at': 1568609864777, 'definition': '(1) dTDP-rhamnose[0] <=> (1) dTDP-L-dihydrostreptose[0]', 'id': 'rxn03805', 'key': 'rxn03805'}>
# rxn03805_c {'c'} set()
# <Node id=89292 labels={'ModelSeedReaction'} properties={'updated_at': 1568609843017, 'equation': '(1) cpd00003[0] + (1) cpd01861[0] <=> (1) cpd00004[0] + (1) cpd00067[0] + (1) cpd00693[0]', 'name': '(R)-Propane-1,2-diol:NAD+ oxidoreductase', 'created_at': 1568609843017, 'definition': '(1) NAD[0] + (1) (R)-1,2-Propanediol[0] <=> (1) NADH[0] + (1) H+[0] + (1) D-Lactaldehyde[0]', 'id': 'rxn02209', 'key': 'rxn02209'}>
# rxn02209_c {'c'} {<Node id=169025 labels={'Function'} properties={'updated_at': 1568619839123, 'created_at': 1568619839123, 'key': 'lactaldehyde reductase (EC 1.1.1.77)'}>}
# <Node id=95757 labels={'ModelSeedReaction'} properties={'updated_at': 1568609929122, 'equation': '(1) cpd00005[0] + (1) cpd00067[0] + (1) cpd15560[0] => (1) cpd00006[0] + (1) cpd15561[0]', 'name': 'quinone reductase', 'created_at': 1568609929122, 'definition': '(1) NADPH[0] + (1) H+[0] + (1) Ubiquinone-8[0] => (1) NADP[0] + (1) Ubiquinol-8[0]', 'id': 'rxn08977', 'key': 'rxn08977'}>
# rxn08977_c {'c'} {<Node id=181412 labels={'FunctionComplex'} properties={'updated_at': 1568634775830, 'created_at': 1568634775830, 'key': 'cpx00309'}>}
# <Node id=87507 labels={'ModelSeedReaction'} properties={'updated_at': 1568609819554, 'equation': '(1) cpd00001[0] + (1) cpd01759[0] => (1) cpd00041[0] + (1) cpd00049[0]', 'name': 'N-Acyl-L-aspartate amidohydrolase', 'created_at': 1568609819554, 'definition': '(1) H2O[0] + (1) N-Acyl-L-aspartate[0] => (1) L-Aspartate[0] + (1) Carboxylic acid[0]', 'id': 'rxn00390', 'key': 'rxn00390'}>
# rxn00390_c {'c'} {<Node id=163244 labels={'Function'} properties={'updated_at': 1568619768074, 'created_at': 1568619768074, 'key': 'nicotinamidase (EC 3.5.1.19)'}>}
# <Node id=97688 labels={'ModelSeedReaction'} properties={'stoichiometry': '-1:cpd00179:0:0:"Maltose";1:cpd01355:0:0:"beta-Maltose"', 'notes': 'GFC|EQC|EQU', 'aliases': 'iAO358: rll_459|Name: aldose 1-epimerase', 'code': '(1) cpd00179[0] <=> (1) cpd01355[0]', 'equation': '(1) cpd00179[0] <=> (1) cpd01355[0]', 'deltag': -0.1, 'is_transport': 0, 'created_at': 1568612906610, 'source': 'Published Model', 'abbreviation': 'rll_459', 'is_obsolete': 0, 'compound_ids': 'cpd00179;cpd01355', 'updated_at': 1568612906610, 'reversibility': '=', 'name': 'aldose 1-epimerase', 'deltagerr': 0.68, 'definition': '(1) Maltose[0] <=> (1) beta-Maltose[0]', 'id': 'rxn11291', 'key': 'rxn11291', 'status': 'OK', 'direction': '='}>
# rxn11291_c {'c'} set()
# <Node id=99184 labels={'ModelSeedReaction'} properties={'stoichiometry': '-1:cpd00017:0:0:"S-Adenosyl-L-methionine";-1:cpd00118:0:0:"Putrescine";1:cpd00011:0:0:"CO2";1:cpd00147:0:0:"5-Methylthioadenosine";1:cpd00264:0:0:"Spermidine"', 'notes': 'GFC|EQC', 'aliases': 'BiGG: SPE3|iIN800: SPE3|Name: Spermidine synthase', 'code': '(1) cpd00017[0] + (1) cpd00118[0] <=> (1) cpd00011[0] + (1) cpd00147[0] + (1) cpd00264[0]', 'equation': '(1) cpd00017[0] + (1) cpd00118[0] => (1) cpd00011[0] + (1) cpd00147[0] + (1) cpd00264[0]', 'deltag': -13.55, 'is_transport': 0, 'created_at': 1568612928936, 'source': 'Secondary Database', 'abbreviation': 'SPE3', 'is_obsolete': 0, 'compound_ids': 'cpd00011;cpd00017;cpd00118;cpd00147;cpd00264', 'updated_at': 1568612928936, 'reversibility': '>', 'name': 'Spermidine synthase', 'deltagerr': 5.02, 'definition': '(1) S-Adenosyl-L-methionine[0] + (1) Putrescine[0] => (1) CO2[0] + (1) 5-Methylthioadenosine[0] + (1) Spermidine[0]', 'id': 'rxn13085', 'key': 'rxn13085', 'status': 'OK', 'direction': '>'}>
# rxn13085_c {'c'} set()
# <Node id=93623 labels={'ModelSeedReaction'} properties={'updated_at': 1568609900876, 'equation': '(1) cpd00146[0] + (1) cpd12548[0] <=> (1) cpd00009[0] + (1) cpd12368[0]', 'name': 'Carbamoyl-phosphate:3-hydroxymethylceph-3-em-4-carboxylate carbamoyltransferase', 'created_at': 1568609900876, 'definition': '(1) Carbamoylphosphate[0] + (1) 3-Hydroxymethyl ceph-3-em-4-carboxylate[0] <=> (1) Phosphate[0] + (1) 3-Carbamoyloxymethylcephem[0]', 'id': 'rxn06636', 'key': 'rxn06636'}>
# rxn06636_c {'c'} {<Node id=166032 labels={'Function'} properties={'updated_at': 1568619800807, 'created_at': 1568619800807, 'key': 'scyllo-inosamine-4-phosphate amidinotransferase (EC 2.1.4.2)'}>}
# <Node id=90838 labels={'ModelSeedReaction'} properties={'updated_at': 1568609863738, 'equation': '(1) cpd00001[0] + (1) cpd00006[0] + (1) cpd04032[0] <=> (1) cpd00005[0] + (2) cpd00067[0] + (1) cpd04031[0]', 'name': 'rxn03760', 'created_at': 1568609863738, 'definition': '(1) H2O[0] + (1) NADP[0] + (1) 4-Hydroxy-6-methylpretetramide[0] <=> (1) NADPH[0] + (2) H+[0] + (1) 4-Dedimethylamino-4-oxo-anhydrotetracycline[0]', 'id': 'rxn03760', 'key': 'rxn03760'}>
# rxn03760_c {'c'} set()
# <Node id=91019 labels={'ModelSeedReaction'} properties={'updated_at': 1568609866792, 'equation': '(1) cpd00017[0] + (1) cpd04329[0] <=> (1) cpd00019[0] + (1) cpd00067[0] + (1) cpd04330[0]', 'name': 'R05676', 'created_at': 1568609866792, 'definition': '(1) S-Adenosyl-L-methionine[0] + (1) N-Acetyl-O-demethylpuromycin[0] <=> (1) S-Adenosyl-homocysteine[0] + (1) H+[0] + (1) N-Acetylpuromycin[0]', 'id': 'rxn03946', 'key': 'rxn03946'}>
# rxn03946_c {'c'} {<Node id=169618 labels={'Function'} properties={'updated_at': 1568619846509, 'created_at': 1568619846509, 'key': 'sterol 24-C-methyltransferase (EC 2.1.1.41)'}>}
# <Node id=95063 labels={'ModelSeedReaction'} properties={'updated_at': 1568609919785, 'equation': '(1) cpd00017[0] + (1) cpd00074[0] + (1) cpd01311[0] <=> (1) cpd00060[0] + (1) cpd00067[0] + (1) cpd00104[0] + (1) cpd03091[0]', 'name': 'Biotin synthase', 'created_at': 1568609919785, 'definition': "(1) S-Adenosyl-L-methionine[0] + (1) S[0] + (1) Dethiobiotin[0] <=> (1) L-Methionine[0] + (1) H+[0] + (1) BIOT[0] + (1) 5'-Deoxyadenosine[0]", 'id': 'rxn08180', 'key': 'rxn08180'}>
# rxn08180_c {'c'} {<Node id=75467 labels={'Function'} properties={'updated_at': 1563778355484, 'created_at': 1563774184179, 'key': 'Biotin synthase (EC 2.8.1.6)'}>}
# <Node id=88598 labels={'ModelSeedReaction'} properties={'updated_at': 1568609834030, 'equation': '(1) cpd00078[0] + (1) cpd02358[0] <=> (1) cpd00036[0] + (1) cpd00292[0]', 'name': 'succinyl-CoA:3-hydroxy-3-methylglutarate CoA-transferase', 'created_at': 1568609834030, 'definition': '(1) Succinyl-CoA[0] + (1) Meglutol[0] <=> (1) Succinate[0] + (1) HMG-CoA[0]', 'id': 'rxn01503', 'key': 'rxn01503'}>
# rxn01503_c {'c'} {<Node id=160514 labels={'Function'} properties={'updated_at': 1568619747631, 'created_at': 1568619747631, 'key': 'cinnamoyl-CoA:phenyllactate CoA-transferase (EC 2.8.3.17)'}>}
# <Node id=92350 labels={'ModelSeedReaction'} properties={'updated_at': 1568609884588, 'equation': '(1) cpd00067[1] + (1) cpd00182[1] <=> (1) cpd00067[0] + (1) cpd00182[0]', 'name': 'TRANS-RXN-203.ce', 'created_at': 1568609884588, 'definition': '(1) H+[1] + (1) Adenosine[1] <=> (1) H+[0] + (1) Adenosine[0]', 'id': 'rxn05318', 'key': 'rxn05318'}>
# rxn05318_c {'e', 'c'} {<Node id=164803 labels={'Function'} properties={'updated_at': 1568619786138, 'created_at': 1568619786138, 'key': 'Nucleoside permease NupC'}>, <Node id=169895 labels={'Function'} properties={'updated_at': 1568619849815, 'created_at': 1568619849815, 'key': 'Nucleoside permease nupG'}>}
# <Node id=91803 labels={'ModelSeedReaction'} properties={'updated_at': 1568609877299, 'equation': '(1) cpd00004[0] + (1) cpd00007[0] + (1) cpd00067[0] + (1) cpd09801[0] => (1) cpd00001[0] + (1) cpd00003[0] + (1) cpd01859[0]', 'name': 'R06926', 'created_at': 1568609877299, 'definition': '(1) NADH[0] + (1) O2[0] + (1) H+[0] + (1) 2-Methylnaphthalene[0] => (1) H2O[0] + (1) NAD[0] + (1) (2-Naphthyl)methanol[0]', 'id': 'rxn04735', 'key': 'rxn04735'}>
# rxn04735_c {'c'} {<Node id=171798 labels={'Function'} properties={'updated_at': 1568619874737, 'created_at': 1568619874737, 'key': '2,6-dihydroxypyridine 3-monooxygenase (EC 1.14.13.10)'}>}
# <Node id=94287 labels={'ModelSeedReaction'} properties={'updated_at': 1568609909745, 'equation': '(1) cpd00017[0] + (1) cpd14618[0] <=> (1) cpd00019[0] + (1) cpd00067[0] + (1) cpd14619[0]', 'name': 'S-adenosyl-L-methionine:demethylspheroidene O-methyltransferase', 'created_at': 1568609909745, 'definition': "(1) S-Adenosyl-L-methionine[0] + (1) 3',4'-Dihydrorhodovibrin[0] <=> (1) S-Adenosyl-homocysteine[0] + (1) H+[0] + (1) 3,4,3',4'-Tetrahydrospirilloxanthin[0]", 'id': 'rxn07360', 'key': 'rxn07360'}>
# rxn07360_c {'c'} {<Node id=162424 labels={'Function'} properties={'updated_at': 1568619758353, 'created_at': 1568619758353, 'key': 'macrocin O-methyltransferase (EC 2.1.1.101)'}>}
# <Node id=90798 labels={'ModelSeedReaction'} properties={'updated_at': 1568609863022, 'equation': '(1) cpd00001[0] + (1) cpd04077[0] <=> (1) cpd00067[0] + (1) cpd00081[0] + (1) cpd01498[0]', 'name': 'R05420', 'created_at': 1568609863022, 'definition': '(1) H2O[0] + (1) 4-Sulfolactone[0] <=> (1) H+[0] + (1) Sulfite[0] + (1) Maleylacetate[0]', 'id': 'rxn03720', 'key': 'rxn03720'}>
# rxn03720_c {'c'} set()
# <Node id=95111 labels={'ModelSeedReaction'} properties={'updated_at': 1568609920458, 'equation': '(2) cpd15539[0] => (1) cpd00100[0] + (1) cpd15429[0]', 'name': 'cardiolipin synthase (periplasmic, n-C16:1)', 'created_at': 1568609920458, 'definition': '(2) Phosphatidylglycerol dihexadec-9-enoyl[0] => (1) Glycerol[0] + (1) cardiolipin tetrahexadec-9-enoyl[0]', 'id': 'rxn08230', 'key': 'rxn08230'}>
# rxn08230_c {'c'} set()
# <Node id=95816 labels={'ModelSeedReaction'} properties={'updated_at': 1568609929922, 'equation': '(0.5) cpd00007[0] + (1) cpd03444[0] => (1) cpd03445[0]', 'name': '2-Octaprenylphenol hydroxylase', 'created_at': 1568609929922, 'definition': '(0.5) O2[0] + (1) 2-Octaprenylphenol[0] => (1) 2-Octaprenyl-6-hydroxyphenol[0]', 'id': 'rxn09044', 'key': 'rxn09044'}>
# rxn09044_c {'c'} set()
# <Node id=87859 labels={'ModelSeedReaction'} properties={'updated_at': 1568609824296, 'equation': '(1) cpd00001[0] + (1) cpd00071[0] + (1) cpd00097[0] => (1) cpd00029[0] + (1) cpd00067[0] + (1) cpd00986[0]', 'name': 'acetaldehyde:pyrroloquinoline-quinone oxidoreductase', 'created_at': 1568609824296, 'definition': '(1) H2O[0] + (1) Acetaldehyde[0] + (1) Pyrroloquinoline-quinone[0] => (1) Acetate[0] + (1) H+[0] + (1) PQQH2[0]', 'id': 'rxn00749', 'key': 'rxn00749'}>
# rxn00749_c {'c'} {<Node id=168212 labels={'Function'} properties={'updated_at': 1568619828924, 'created_at': 1568619828924, 'key': 'carboxylate reductase (EC 1.2.99.6)'}>}
# <Node id=100255 labels={'ModelSeedReaction'} properties={'aliases': 'AraCyc: 3.4.22.54-RXN; NUCLEOSIDE-DIP-KIN-RXN; R15-RXN; RXN-12386; RXN-12949; RXN-8315; RXN0-5305|BrachyCyc: NUCLEOSIDE-DIP-KIN-RXN; TRANS-RXNAVI-26352|ChlamyCyc: RXN4LZ-751|KEGG: R00124; R02121; R02996; R03852; R04168; R04193; R04422; R07480; R08679|MetaCyc: 2.4.1.100-RXN; 2.4.1.161-RXN; 3.4.22.54-RXN; 3.4.22.55-RXN; 3.4.22.56-RXN; 3.4.22.57-RXN; 3.4.22.58-RXN; 3.4.22.59-RXN; 3.4.22.60-RXN; 3.4.22.61-RXN; 3.4.22.62-RXN; 3.4.22.63-RXN; 3.4.22.64-RXN; 3.4.22.65-RXN; ALDOSE-BETA-FRUCTOSYLTRANSFERASE-RXN; ARYLSULFATE-SULFOTRANSFERASE-RXN; DEXTRIN-DEXTRANASE-RXN; NUCLEOSIDE-DEOXYRIBOSYLTRANSFERASE-RXN; NUCLEOSIDE-DIP-KIN-RXN; NUCLEOSIDE-RIBOSYLTRANSFERASE-RXN; PGLYCEROLTRANSII-RXN; RXN-12386; RXN-12947; RXN-12948; RXN-12949; RXN-12950; RXN-13070; RXN-8315; RXN0-5305|Name: ATP:ADP phosphatransferase; N-(4-aminobutylidene)-[enzyme]-lysine:[eIF5A-precursor]-lysineN-4-aminobutylidenetransferase; alpha-D-Aldosyl-beta-D-fructoside:aldose1-beta-D-fructosyltransferase', 'code': ' <=> ', 'equation': ' <=> ', 'deltag': 10000000.0, 'is_transport': 0, 'created_at': 1568612944402, 'pathways': 'MetaCyc: Degradation (Degradation/Utilization/Assimilation); Lipid-Biosynthesis (Fatty Acid and Lipid Biosynthesis); Nicotine-Degradation (Nicotine Degradation); Other-Degradation (Degradation/Utilization/Assimilation-Other); P181-PWY (nicotine degradation I (pyridine pathway)); PWY-6804 (diacylglycerol biosynthesis (PUFA enrichment in oilseed))|KEGG: rn00230 (Purine metabolism); rn01110 (Biosynthesis of secondary metabolites)', 'ec_numbers': '2.4.1.162|2.4.2.5|2.7.4.6|2.7.8.-|2.8.2.22', 'source': 'Orphan', 'abbreviation': 'N-(4-aminobutylidene)-[enzyme]-lysine:[eIF5A-precursor]-lysineN-4-aminobutylidenetransferase', 'is_obsolete': 1, 'updated_at': 1568612944402, 'reversibility': '?', 'name': 'N-(4-aminobutylidene)-[enzyme]-lysine:[eIF5A-precursor]-lysineN-4-aminobutylidenetransferase', 'deltagerr': 10000000.0, 'definition': ' <=> ', 'id': 'rxn14312', 'key': 'rxn14312', 'linked_reaction': 'rxn14003;rxn14046;rxn14111;rxn14154;rxn14266;rxn14325;rxn14393', 'direction': '=', 'status': 'EMPTY'}>
# rxn14312_c set() set()
# <Node id=87185 labels={'ModelSeedReaction'} properties={'updated_at': 1568609814945, 'equation': '(1) cpd00001[0] + (1) cpd00002[0] => (1) cpd00008[0] + (1) cpd00009[0] + (1) cpd00067[0]', 'name': 'ATP phosphohydrolase', 'created_at': 1568609814945, 'definition': '(1) H2O[0] + (1) ATP[0] => (1) ADP[0] + (1) Phosphate[0] + (1) H+[0]', 'id': 'rxn00062', 'key': 'rxn00062'}>
# rxn00062_c {'c'} {<Node id=164608 labels={'Function'} properties={'updated_at': 1568619783894, 'created_at': 1568619783894, 'key': 'Mn2+-dependent ADP-ribose/CDP-alcohol diphosphatase (EC 3.6.1.53)'}>, <Node id=169856 labels={'Function'} properties={'updated_at': 1568619849323, 'created_at': 1568619849323, 'key': 'dynein ATPase (EC 3.6.4.2)'}>, <Node id=167042 labels={'Function'} properties={'updated_at': 1568619813324, 'created_at': 1568619813324, 'key': 'capsular-polysaccharide-transporting ATPase (EC 3.6.3.38)'}>, <Node id=164995 labels={'Function'} properties={'updated_at': 1568619788388, 'created_at': 1568619788388, 'key': 'mitochondrial protein-transporting ATPase (EC 3.6.3.51)'}>, <Node id=173700 labels={'Function'} properties={'updated_at': 1568619898525, 'created_at': 1568619898525, 'key': 'Na+/K+-exchanging ATPase (EC 3.6.3.9)'}>, <Node id=162949 labels={'Function'} properties={'updated_at': 1568619764645, 'created_at': 1568619764645, 'key': 'maltose-transporting ATPase (EC 3.6.3.19)'}>, <Node id=163973 labels={'Function'} properties={'updated_at': 1568619776381, 'created_at': 1568619776381, 'key': 'Mg2+-importing ATPase (EC 3.6.3.2)'}>, <Node id=167175 labels={'Function'} properties={'updated_at': 1568619814970, 'created_at': 1568619814970, 'key': 'nitrate-transporting ATPase (EC 3.6.3.26)'}>, <Node id=163208 labels={'Function'} properties={'updated_at': 1568619767706, 'created_at': 1568619767706, 'key': 'RNA helicase (EC 3.6.4.13)'}>, <Node id=165130 labels={'Function'} properties={'updated_at': 1568619789984, 'created_at': 1568619789984, 'key': 'taurine-transporting ATPase (EC 3.6.3.36)'}>, <Node id=172427 labels={'Function'} properties={'updated_at': 1568619882719, 'created_at': 1568619882719, 'key': 'myosin ATPase (EC 3.6.4.1)'}>, <Node id=163344 labels={'Function'} properties={'updated_at': 1568619769041, 'created_at': 1568619769041, 'key': 'cadmium-transporting ATPase (EC 3.6.3.46)'}>, <Node id=165907 labels={'Function'} properties={'updated_at': 1568619799244, 'created_at': 1568619799244, 'key': 'alpha-factor-transporting ATPase (EC 3.6.3.48)'}>, <Node id=163605 labels={'Function'} properties={'updated_at': 1568619772137, 'created_at': 1568619772137, 'key': 'nucleoplasmin ATPase (EC 3.6.4.11)'}>, <Node id=169366 labels={'Function'} properties={'updated_at': 1568619843402, 'created_at': 1568619843402, 'key': 'arsenite-transporting ATPase (EC 3.6.3.16)'}>, <Node id=171672 labels={'Function'} properties={'updated_at': 1568619872311, 'created_at': 1568619872311, 'key': 'chloroplast protein-transporting ATPase (EC 3.6.3.52)'}>, <Node id=173849 labels={'Function'} properties={'updated_at': 1568619900313, 'created_at': 1568619900313, 'key': 'oligopeptide-transporting ATPase (EC 3.6.3.23)'}>, <Node id=166424 labels={'Function'} properties={'updated_at': 1568619805684, 'created_at': 1568619805684, 'key': 'non-chaperonin molecular chaperone ATPase (EC 3.6.4.10)'}>, <Node id=166301 labels={'Function'} properties={'updated_at': 1568619804143, 'created_at': 1568619804143, 'key': 'manganese-transporting ATPase (EC 3.6.3.35)'}>, <Node id=163358 labels={'Function'} properties={'updated_at': 1568619769191, 'created_at': 1568619769191, 'key': 'microtubule-severing ATPase (EC 3.6.4.3)'}>, <Node id=168737 labels={'Function'} properties={'updated_at': 1568619835498, 'created_at': 1568619835498, 'key': 'heme-transporting ATPase (EC 3.6.3.41)'}>, <Node id=164900 labels={'Function'} properties={'updated_at': 1568619787274, 'created_at': 1568619787274, 'key': 'peroxisome-assembly ATPase (EC 3.6.4.7)'}>, <Node id=171046 labels={'Function'} properties={'updated_at': 1568619864199, 'created_at': 1568619864199, 'key': 'Ag+-exporting ATPase (EC 3.6.3.53)'}>, <Node id=160424 labels={'Function'} properties={'updated_at': 1568619733136, 'created_at': 1568619733136, 'key': 'nucleoside-triphosphate diphosphatase (EC 3.6.1.19)'}>, <Node id=161832 labels={'Function'} properties={'updated_at': 1568619750948, 'created_at': 1568619750948, 'key': 'p ...
# <Node id=88198 labels={'ModelSeedReaction'} properties={'updated_at': 1568609828689, 'equation': '(1) cpd00003[0] + (1) cpd02566[0] <=> (1) cpd00004[0] + (1) cpd00067[0] + (1) cpd00168[0]', 'name': '2,3-dihydro-2,3-dihydroxybenzoate:NAD+ oxidoreductase', 'created_at': 1568609828689, 'definition': '(1) NAD[0] + (1) 2,3-Dihydroxy-2,3-dihydrobenzoate[0] <=> (1) NADH[0] + (1) H+[0] + (1) 2,3-Dihydroxybenzoate[0]', 'id': 'rxn01094', 'key': 'rxn01094'}>
# rxn01094_c {'c'} {<Node id=84837 labels={'Function'} properties={'updated_at': 1563774576966, 'created_at': 1563774576966, 'key': '2,3-dihydro-2,3-dihydroxybenzoate dehydrogenase (EC 1.3.1.28) [enterobactin] siderophore'}>, <Node id=169407 labels={'Function'} properties={'updated_at': 1568619843875, 'created_at': 1568619843875, 'key': 'progesterone 5alpha-reductase (EC 1.3.1.30)'}>}
# <Node id=93463 labels={'ModelSeedReaction'} properties={'updated_at': 1568609898738, 'equation': '(1) cpd12381[0] => (1) cpd01293[0] + (1) cpd11623[0]', 'name': '(5-L-Glutamyl)-L-amino-acid 5-glutamyltransferase (cyclizing)', 'created_at': 1568609898738, 'definition': '(1) (5-L-Glutamyl)-L-amino acid[0] => (1) 5-Oxoproline[0] + (1) L-Amino acid[0]', 'id': 'rxn06472', 'key': 'rxn06472'}>
# rxn06472_c {'c'} {<Node id=171938 labels={'Function'} properties={'updated_at': 1568619876491, 'created_at': 1568619876491, 'key': 'arginyltransferase (EC 2.3.2.8)'}>}
# <Node id=97311 labels={'ModelSeedReaction'} properties={'updated_at': 1568609950474, 'equation': '(2) cpd00001[0] + (1) cpd00038[0] => (2) cpd00009[0] + (3) cpd00067[0] + (1) cpd00126[0]', 'name': 'GTP diphosphohydrolase', 'created_at': 1568609950474, 'definition': '(2) H2O[0] + (1) GTP[0] => (2) Phosphate[0] + (3) H+[0] + (1) GMP[0]', 'id': 'rxn10791', 'key': 'rxn10791'}>
# rxn10791_c {'c'} set()
# <Node id=89774 labels={'ModelSeedReaction'} properties={'updated_at': 1568609849139, 'equation': '(1) cpd00002[0] + (1) cpd01320[0] => (1) cpd00008[0] + (1) cpd00067[0] + (1) cpd02139[0]', 'name': "ATP:hygromycin-B 7''-O-phosphotransferase", 'created_at': 1568609849139, 'definition': "(1) ATP[0] + (1) Hygromycin B[0] => (1) ADP[0] + (1) H+[0] + (1) 7''-O-Phosphohygromycin[0]", 'id': 'rxn02674', 'key': 'rxn02674'}>
# rxn02674_c {'c'} {<Node id=160561 labels={'Function'} properties={'updated_at': 1568619734711, 'created_at': 1568619734711, 'key': 'xylitol kinase (EC 2.7.1.122)'}>}
# <Node id=97093 labels={'ModelSeedReaction'} properties={'updated_at': 1568609947565, 'equation': '(1) cpd00116[0] + (1) cpd02246[0] <= (1) cpd00001[0] + (1) cpd02438[0]', 'name': 'Methanol: coenzyme M methyltransferase', 'created_at': 1568609947565, 'definition': '(1) Methanol[0] + (1) CoM[0] <= (1) H2O[0] + (1) Methyl CoM[0]', 'id': 'rxn10568', 'key': 'rxn10568'}>
# rxn10568_c {'c'} set()
# <Node id=98175 labels={'ModelSeedReaction'} properties={'stoichiometry': '-1:cpd00006:0:0:"NADP";-1:cpd00667:0:0:"11-cis-Retinol";1:cpd00005:0:0:"NADPH";1:cpd00067:0:0:"H+";1:cpd01430:0:0:"11-cis-Retinal"', 'aliases': 'JP_Creinhardtii_MSB: R_CRETINOLOR2|KEGG: R08380|MetaCyc: RXN-13363|Name: 11-cis-retinol dehydrogenase; 11-cis-retinol: NADP+ oxidoreductase', 'notes': 'GFC|EQC|EQU', 'code': '(1) cpd00006[0] + (1) cpd00667[0] <=> (1) cpd00005[0] + (1) cpd01430[0]', 'equation': '(1) cpd00006[0] + (1) cpd00667[0] <=> (1) cpd00005[0] + (1) cpd00067[0] + (1) cpd01430[0]', 'deltag': 7.16, 'is_transport': 0, 'created_at': 1568612914010, 'pathways': 'KEGG: rn00830 (Retinol metabolism)', 'ec_numbers': '1.1.1.-', 'source': 'Primary Database', 'abbreviation': 'R08380', 'is_obsolete': 0, 'compound_ids': 'cpd00005;cpd00006;cpd00067;cpd00667;cpd01430', 'updated_at': 1568612914010, 'reversibility': '=', 'name': '11-cis-retinol: NADP+ oxidoreductase', 'deltagerr': 0.74, 'definition': '(1) NADP[0] + (1) 11-cis-Retinol[0] <=> (1) NADPH[0] + (1) H+[0] + (1) 11-cis-Retinal[0]', 'id': 'rxn11891', 'key': 'rxn11891', 'status': 'OK', 'direction': '='}>
# rxn11891_c {'c'} set()
# <Node id=95522 labels={'ModelSeedReaction'} properties={'updated_at': 1568609925951, 'equation': '(1) cpd00002[0] + (1) cpd15488[0] => (1) cpd00008[0] + (1) cpd00067[0] + (1) cpd15550[0]', 'name': 'LPS heptose kinase II (LPS core synthesis)', 'created_at': 1568609925951, 'definition': '(1) ATP[0] + (1) heptosyl-phospho-heptosyl-heptosyl-kdo2-lipidA[0] => (1) ADP[0] + (1) H+[0] + (1) phospho-heptosyl-phospho-heptosyl-heptosyl-kdo2-lipidA[0]', 'id': 'rxn08709', 'key': 'rxn08709'}>
# rxn08709_c {'c'} {<Node id=163670 labels={'Function'} properties={'updated_at': 1568619772882, 'created_at': 1568619772882, 'key': 'Lipopolysaccharide core biosynthesis protein RfaY'}>}
# <Node id=97861 labels={'ModelSeedReaction'} properties={'stoichiometry': '-1:cpd00001:0:0:"H2O";-1:cpd00947:0:0:"LacCer";1:cpd00108:0:0:"Galactose";1:cpd00878:0:0:"Glucocerebroside"', 'aliases': 'KEGG: R03355; R06099|iRS1563: R_R03355_c|Name: beta-D-Galactosyl-1,4-beta-D-glucosylceramide galactohydrolase', 'notes': 'GFP|EQP', 'code': '(1) cpd00001[0] + (1) cpd00947[0] <=> (1) cpd00108[0] + (1) cpd00878[0]', 'equation': '(1) cpd00001[0] + (1) cpd00947[0] => (1) cpd00108[0] + (1) cpd00878[0]', 'deltag': 10000000.0, 'is_transport': 0, 'created_at': 1568612909260, 'pathways': 'KEGG: rn00600 (Sphingolipid metabolism)', 'ec_numbers': '3.2.1.23', 'source': 'Primary Database', 'abbreviation': 'R03355', 'is_obsolete': 0, 'compound_ids': 'cpd00001;cpd00108;cpd00878;cpd00947', 'updated_at': 1568612909260, 'reversibility': '?', 'name': 'beta-D-Galactosyl-1,4-beta-D-glucosylceramide galactohydrolase', 'deltagerr': 10000000.0, 'definition': '(1) H2O[0] + (1) LacCer[0] => (1) Galactose[0] + (1) Glucocerebroside[0]', 'id': 'rxn11567', 'key': 'rxn11567', 'status': 'OK', 'direction': '>'}>
# rxn11567_c {'c'} {<Node id=82756 labels={'Function'} properties={'updated_at': 1563774522258, 'created_at': 1563774522258, 'key': 'beta-galactosidase (EC 3.2.1.23)'}>}
# <Node id=87540 labels={'ModelSeedReaction'} properties={'updated_at': 1568609820010, 'equation': '(1) cpd00022[0] + (1) cpd00054[0] => (1) cpd00010[0] + (1) cpd00722[0]', 'name': 'acetyl-CoA:L-serine O-acetyltransferase', 'created_at': 1568609820010, 'definition': '(1) Acetyl-CoA[0] + (1) L-Serine[0] => (1) CoA[0] + (1) O-Acetyl-L-serine[0]', 'id': 'rxn00423', 'key': 'rxn00423'}>
# rxn00423_c {'c'} {<Node id=167521 labels={'Function'} properties={'updated_at': 1568619820198, 'created_at': 1568619820198, 'key': 'D-tryptophan N-acetyltransferase (EC 2.3.1.34)'}>, <Node id=75082 labels={'Function'} properties={'updated_at': 1563778338829, 'created_at': 1563774176087, 'key': 'Serine acetyltransferase (EC 2.3.1.30)'}>}
# <Node id=96887 labels={'ModelSeedReaction'} properties={'updated_at': 1568609944692, 'equation': '(24) cpd00026[0] + (1) cpd15746[0] <=> (24) cpd00014[0] + (1) cpd15755[0]', 'name': 'palmitoyl-lipoteichoic acid synthesis (n=24), linked, glucose substituted', 'created_at': 1568609944692, 'definition': '(24) UDP-glucose[0] + (1) Palmitoyllipoteichoic acid (n=24), linked, unsubstituted[0] <=> (24) UDP[0] + (1) Palmitoyllipoteichoic acid (n=24), linked, glucose substituted[0]', 'id': 'rxn10298', 'key': 'rxn10298'}>
# rxn10298_c {'c'} {<Node id=76000 labels={'Function'} properties={'updated_at': 1563778380996, 'created_at': 1563774196397, 'key': 'Poly(glycerol-phosphate) alpha-glucosyltransferase (EC 2.4.1.52)'}>}
# <Node id=87481 labels={'ModelSeedReaction'} properties={'updated_at': 1568609819164, 'equation': '(1) cpd00002[0] + (1) cpd00046[0] + (1) cpd00067[0] <=> (1) cpd00008[0] + (1) cpd00096[0]', 'name': 'ATP:CMP phosphotransferase', 'created_at': 1568609819164, 'definition': '(1) ATP[0] + (1) CMP[0] + (1) H+[0] <=> (1) ADP[0] + (1) CDP[0]', 'id': 'rxn00364', 'key': 'rxn00364'}>
# rxn00364_c {'c'} {<Node id=170429 labels={'Function'} properties={'updated_at': 1568619856509, 'created_at': 1568619856509, 'key': 'Cytidylate kinase (EC 2.7.4.14)'}>, <Node id=172431 labels={'Function'} properties={'updated_at': 1568619882769, 'created_at': 1568619882769, 'key': 'farnesyl-diphosphate kinase (EC 2.7.4.18)'}>}
# <Node id=92578 labels={'ModelSeedReaction'} properties={'updated_at': 1568609886860, 'equation': '(1) cpd00067[1] + (1) cpd00137[1] + (1) cpd00244[1] <=> (1) cpd00067[0] + (1) cpd00137[0] + (1) cpd00244[0]', 'name': 'citrate transport in via Ni complex', 'created_at': 1568609886860, 'definition': '(1) H+[1] + (1) Citrate[1] + (1) Ni2+[1] <=> (1) H+[0] + (1) Citrate[0] + (1) Ni2+[0]', 'id': 'rxn05521', 'key': 'rxn05521'}>
# rxn05521_c {'e', 'c'} set()
# <Node id=98275 labels={'ModelSeedReaction'} properties={'stoichiometry': '-1:cpd00001:0:0:"H2O";-1:cpd00067:0:0:"H+";-1:cpd03477:0:0:"Vitamin K1 oxide";-1:cpd12845:0:0:"Gla protein";1:cpd00007:0:0:"O2";1:cpd00011:0:0:"CO2";1:cpd12844:0:0:"Phytonadiol";1:cpd12846:0:0:"Gla protein precursor"', 'aliases': 'KEGG: R05144|Name: peptidyl-glutamate 4-carboxylase (2-methyl-3-phytyl-1,4-naphthoquinone-epoxidizing)', 'notes': 'GFP|EQP', 'code': '(1) cpd00001[0] + (1) cpd03477[0] + (1) cpd12845[0] <=> (1) cpd00007[0] + (1) cpd00011[0] + (1) cpd12844[0] + (1) cpd12846[0]', 'equation': '(1) cpd00001[0] + (1) cpd00067[0] + (1) cpd03477[0] + (1) cpd12845[0] <= (1) cpd00007[0] + (1) cpd00011[0] + (1) cpd12844[0] + (1) cpd12846[0]', 'deltag': 10000000.0, 'is_transport': 0, 'created_at': 1568612915459, 'pathways': 'KEGG: rn00130 (Ubiquinone and other terpenoid-quinone biosynthesis); rn01110 (Biosynthesis of secondary metabolites)', 'ec_numbers': '4.1.1.90', 'source': 'Primary Database', 'abbreviation': 'R05144', 'is_obsolete': 0, 'compound_ids': 'cpd00001;cpd00007;cpd00011;cpd00067;cpd03477;cpd12844;cpd12845;cpd12846', 'updated_at': 1568612915459, 'reversibility': '?', 'name': 'peptidyl-glutamate 4-carboxylase (2-methyl-3-phytyl-1,4-naphthoquinone-epoxidizing)', 'deltagerr': 10000000.0, 'definition': '(1) H2O[0] + (1) H+[0] + (1) Vitamin K1 oxide[0] + (1) Gla protein[0] <= (1) O2[0] + (1) CO2[0] + (1) Phytonadiol[0] + (1) Gla protein precursor[0]', 'id': 'rxn12005', 'key': 'rxn12005', 'status': 'OK', 'direction': '<'}>
# rxn12005_c {'c'} {<Node id=168873 labels={'Function'} properties={'updated_at': 1568619837216, 'created_at': 1568619837216, 'key': 'propionyl-CoA carboxylase (EC 6.4.1.3)'}>}
# <Node id=87984 labels={'ModelSeedReaction'} properties={'updated_at': 1568609825881, 'equation': '(1) cpd00481[0] <=> (1) cpd00120[0]', 'name': '2-Methylpropanoyl-CoA CoA-carbonylmutase', 'created_at': 1568609825881, 'definition': '(1) Isobutyryl-CoA[0] <=> (1) Butyryl-CoA[0]', 'id': 'rxn00877', 'key': 'rxn00877'}>
# rxn00877_c {'c'} {<Node id=166962 labels={'Function'} properties={'updated_at': 1568619812320, 'created_at': 1568619812320, 'key': 'squalene---hopene cyclase (EC 5.4.99.17)'}>}
# <Node id=97915 labels={'ModelSeedReaction'} properties={'stoichiometry': '-1:cpd03216:0:0:"Neurosporene";1:cpd03219:0:0:"beta-Zeacarotene"', 'aliases': 'AraCyc: RXN-8038|ChlamyCyc: RXN-8038|CornCyc: RXN-8038|KEGG: R04801|MetaCyc: RXN-8038|Name: carotenoid beta-end group lyase (decyclizing)', 'notes': 'GFC|EQC|EQU', 'code': '(1) cpd03216[0] <=> (1) cpd03219[0]', 'equation': '(1) cpd03216[0] => (1) cpd03219[0]', 'deltag': -33.81, 'is_transport': 0, 'created_at': 1568612910088, 'pathways': 'KEGG: rn00906 (Carotenoid biosynthesis)', 'ec_numbers': '5.5.1.-|5.5.1.19', 'source': 'Primary Database', 'abbreviation': 'R04801', 'is_obsolete': 0, 'compound_ids': 'cpd03216;cpd03219', 'updated_at': 1568612910088, 'reversibility': '>', 'name': 'carotenoid beta-end group lyase (decyclizing)', 'deltagerr': 1.82, 'definition': '(1) Neurosporene[0] => (1) beta-Zeacarotene[0]', 'id': 'rxn11625', 'key': 'rxn11625', 'linked_reaction': 'rxn24576', 'status': 'OK', 'direction': '>'}>
# rxn11625_c {'c'} {<Node id=170128 labels={'Function'} properties={'updated_at': 1568619852758, 'created_at': 1568619852758, 'key': 'tocopherol cyclase (EC 5.5.1.24)'}>}
# <Node id=87728 labels={'ModelSeedReaction'} properties={'updated_at': 1568609822561, 'equation': '(1) cpd00006[0] + (1) cpd00080[0] <=> (1) cpd00005[0] + (1) cpd00067[0] + (1) cpd00102[0]', 'name': 'sn-glycerol-3-phosphate:NADP+ 1-oxidoreductase', 'created_at': 1568609822561, 'definition': '(1) NADP[0] + (1) Glycerol-3-phosphate[0] <=> (1) NADPH[0] + (1) H+[0] + (1) Glyceraldehyde3-phosphate[0]', 'id': 'rxn00613', 'key': 'rxn00613'}>
# rxn00613_c {'c'} {<Node id=171859 labels={'Function'} properties={'updated_at': 1568619875508, 'created_at': 1568619875508, 'key': 'glycerol-3-phosphate 1-dehydrogenase (NADP+) (EC 1.1.1.177)'}>}
# <Node id=92615 labels={'ModelSeedReaction'} properties={'updated_at': 1568609887330, 'equation': '(1) cpd00067[1] + (1) cpd00106[1] <=> (1) cpd00067[0] + (1) cpd00106[0]', 'name': 'Transport of dicarboxylates, extracellular', 'created_at': 1568609887330, 'definition': '(1) H+[1] + (1) Fumarate[1] <=> (1) H+[0] + (1) Fumarate[0]', 'id': 'rxn05561', 'key': 'rxn05561'}>
# rxn05561_c {'e', 'c'} {<Node id=74584 labels={'Function'} properties={'updated_at': 1563778318990, 'created_at': 1563774165597, 'key': 'TRAP-type C4-dicarboxylate transport system, periplasmic component'}>, <Node id=172099 labels={'Function'} properties={'updated_at': 1568619878589, 'created_at': 1568619878589, 'key': 'C4-dicarboxylate transport protein'}>, <Node id=160708 labels={'Function'} properties={'updated_at': 1568619736471, 'created_at': 1568619736471, 'key': 'C4-dicarboxylate transporter DcuC (TC 2.A.61.1.1)'}>, <Node id=75208 labels={'Function'} properties={'updated_at': 1563778344717, 'created_at': 1563774178810, 'key': 'Anaerobic C4-dicarboxylate transporter DcuB'}>}
# <Node id=98786 labels={'ModelSeedReaction'} properties={'stoichiometry': '-1:cpd00067:1:0:"H+";-1:cpd03963:1:0:"Biuret";1:cpd00067:0:0:"H+";1:cpd03963:0:0:"Biuret"', 'aliases': 'Name: Biuret transport via proton symport', 'notes': 'GFC|EQC', 'code': '(1) cpd03963[1] <=> (1) cpd03963[0]', 'equation': '(1) cpd00067[1] + (1) cpd03963[1] <=> (1) cpd00067[0] + (1) cpd03963[0]', 'deltag': 0.0, 'is_transport': 1, 'created_at': 1568612923029, 'source': 'Orphan', 'abbreviation': 'Biuret transport via proton symport', 'is_obsolete': 0, 'compound_ids': 'cpd00067;cpd03963', 'updated_at': 1568612923029, 'reversibility': '=', 'name': 'Biuret transport via proton symport', 'deltagerr': 1.97, 'definition': '(1) H+[1] + (1) Biuret[1] <=> (1) H+[0] + (1) Biuret[0]', 'id': 'rxn12564', 'key': 'rxn12564', 'status': 'OK', 'direction': '='}>
# rxn12564_c {'e', 'c'} set()
# <Node id=95890 labels={'ModelSeedReaction'} properties={'updated_at': 1568609930886, 'equation': '(1) cpd00001[0] + (1) cpd15524[0] => (1) cpd00067[0] + (1) cpd00214[0] + (1) cpd15355[0]', 'name': 'Phospholipase A1 (phosphatidate, n-C16:0) (periplasm)', 'created_at': 1568609930886, 'definition': '(1) H2O[0] + (1) 1,2-dihexadecanoyl-sn-glycerol 3-phosphate[0] => (1) H+[0] + (1) Palmitate[0] + (1) 2-hexadecanoyl-sn-glycerol 3-phosphate[0]', 'id': 'rxn09126', 'key': 'rxn09126'}>
# rxn09126_c {'c'} {<Node id=162678 labels={'Function'} properties={'updated_at': 1568619761489, 'created_at': 1568619761489, 'key': 'Phospholipase A1 precursor (EC 3.1.1.32, EC 3.1.1.4)'}>}
# <Node id=90587 labels={'ModelSeedReaction'} properties={'updated_at': 1568609859981, 'equation': '(2) cpd00001[0] + (2) cpd00067[0] + (1) cpd03816[0] => (1) cpd00011[0] + (2) cpd00013[0] + (1) cpd03819[0]', 'name': 'Methylenediurea aminohydrolase', 'created_at': 1568609859981, 'definition': '(2) H2O[0] + (2) H+[0] + (1) Methylenediurea[0] => (1) CO2[0] + (2) NH3[0] + (1) N-(Hydroxymethyl)urea[0]', 'id': 'rxn03505', 'key': 'rxn03505'}>
# rxn03505_c {'c'} {<Node id=170886 labels={'Function'} properties={'updated_at': 1568619862249, 'created_at': 1568619862249, 'key': 'allantoicase (EC 3.5.3.4)'}>}
# <Node id=88289 labels={'ModelSeedReaction'} properties={'updated_at': 1568609829947, 'equation': '(1) cpd00013[0] + (1) cpd00193[0] => (1) cpd00048[0] + (2) cpd00067[0] + (1) cpd02402[0]', 'name': 'Adenylyl-sulfate:ammonia adenylyltransferase', 'created_at': 1568609829947, 'definition': "(1) NH3[0] + (1) APS[0] => (1) Sulfate[0] + (2) H+[0] + (1) Adenosine 5'-phosphoramidate[0]", 'id': 'rxn01185', 'key': 'rxn01185'}>
# rxn01185_c {'c'} {<Node id=160768 labels={'Function'} properties={'updated_at': 1568619737170, 'created_at': 1568619737170, 'key': 'anthranilate adenylyltransferase (EC 2.7.7.55)'}>}
# <Node id=89448 labels={'ModelSeedReaction'} properties={'updated_at': 1568609845020, 'equation': '(1) cpd00017[0] + (1) cpd00854[0] <=> (1) cpd00019[0] + (1) cpd00067[0] + (1) cpd03312[0]', 'name': 'S-Adenosyl-L-methionine:catechol O-methyltransferase', 'created_at': 1568609845020, 'definition': '(1) S-Adenosyl-L-methionine[0] + (1) Homoprotocatechuate[0] <=> (1) S-Adenosyl-homocysteine[0] + (1) H+[0] + (1) Homovanillate[0]', 'id': 'rxn02367', 'key': 'rxn02367'}>
# rxn02367_c {'c'} {<Node id=168169 labels={'Function'} properties={'updated_at': 1568619828374, 'created_at': 1568619828374, 'key': 'methylated-DNA---[protein]-cysteine S-methyltransferase (EC 2.1.1.63)'}>}
# <Node id=87718 labels={'ModelSeedReaction'} properties={'updated_at': 1568609822422, 'equation': '(1) cpd00006[0] + (1) cpd00804[0] <=> (1) cpd00005[0] + (1) cpd00067[0] + (1) cpd00079[0]', 'name': 'D-Sorbitol 6-phosphate:NADP+ 1-oxidoreductase', 'created_at': 1568609822422, 'definition': '(1) NADP[0] + (1) Sorbitol 6-phosphate[0] <=> (1) NADPH[0] + (1) H+[0] + (1) D-glucose-6-phosphate[0]', 'id': 'rxn00603', 'key': 'rxn00603'}>
# rxn00603_c {'c'} {<Node id=162824 labels={'Function'} properties={'updated_at': 1568619763195, 'created_at': 1568619763195, 'key': 'aldose-6-phosphate reductase (NADPH) (EC 1.1.1.200)'}>}
# <Node id=99581 labels={'ModelSeedReaction'} properties={'stoichiometry': '-1:cpd00001:0:0:"H2O";-1:cpd16902:0:0:"alpha1-trehalose-monomyclolate-phosphate";1:cpd00009:0:0:"Phosphate";1:cpd00067:0:0:"H+";1:cpd16901:0:0:"alpha1-trehalose-monomyclolate"', 'notes': 'GFP|EQP', 'code': '(1) cpd00001[0] + (1) cpd16902[0] <=> (1) cpd00009[0] + (1) cpd16901[0]', 'equation': '(1) cpd00001[0] + (1) cpd16902[0] <=> (1) cpd00009[0] + (1) cpd00067[0] + (1) cpd16901[0]', 'deltag': 10000000.0, 'is_transport': 0, 'created_at': 1568612934615, 'source': 'Orphan', 'abbreviation': 'TMMP1', 'is_obsolete': 0, 'compound_ids': 'cpd00001;cpd00009;cpd00067;cpd16901;cpd16902', 'updated_at': 1568612934615, 'reversibility': '?', 'name': 'trehalose-monomycolate-phosphatase', 'deltagerr': 10000000.0, 'definition': '(1) H2O[0] + (1) alpha1-trehalose-monomyclolate-phosphate[0] <=> (1) Phosphate[0] + (1) H+[0] + (1) alpha1-trehalose-monomyclolate[0]', 'id': 'rxn13549', 'key': 'rxn13549', 'status': 'OK', 'direction': '='}>
# rxn13549_c {'c'} set()
# ...
# rxn00747_c {'c'} {<Node id=167953 labels={'Function'} properties={'updated_at': 1568619825686, 'created_at': 1568619825686, 'key': 'arabinose-5-phosphate isomerase (EC 5.3.1.13)'}>, <Node id=75148 labels={'Function'} properties={'updated_at': 1563778342021, 'created_at': 1563774177497, 'key': 'Triosephosphate isomerase (EC 5.3.1.1)'}>, <Node id=81039 labels={'Function'} properties={'updated_at': 1563774479863, 'created_at': 1563774479863, 'key': 'Glyceraldehyde-3-phosphate ketol-isomerase (EC 5.3.1.1)'}>}
# <Node id=88432 labels={'ModelSeedReaction'} properties={'updated_at': 1568609831928, 'equation': '(1) cpd00349[0] <=> (1) cpd00095[0] + (1) cpd00236[0]', 'name': 'Sedoheptulose 1,7-bisphosphate D-glyceraldehyde-3-phosphate-lyase', 'created_at': 1568609831928, 'definition': '(1) Sedoheptulose 1,7-bisphosphate[0] <=> (1) Glycerone-phosphate[0] + (1) D-Erythrose4-phosphate[0]', 'id': 'rxn01334', 'key': 'rxn01334'}>
# rxn01334_c {'c'} {<Node id=171244 labels={'Function'} properties={'updated_at': 1568619866621, 'created_at': 1568619866621, 'key': 'L-fuculose-phosphate aldolase (EC 4.1.2.17)'}>, <Node id=79165 labels={'Function'} properties={'updated_at': 1563774446602, 'created_at': 1563774437060, 'key': 'Fructose-bisphosphate aldolase class I (EC 4.1.2.13)'}>, <Node id=75006 labels={'Function'} properties={'updated_at': 1563778335843, 'created_at': 1563774174455, 'key': 'Fructose-bisphosphate aldolase class II (EC 4.1.2.13)'}>}
# <Node id=87937 labels={'ModelSeedReaction'} properties={'updated_at': 1568609825289, 'equation': '(1) cpd00113[0] <=> (1) cpd00202[0]', 'name': 'Isopentenyl-diphosphate delta3-delta2-isomerase', 'created_at': 1568609825289, 'definition': '(1) Isopentenyldiphosphate[0] <=> (1) DMAPP[0]', 'id': 'rxn00830', 'key': 'rxn00830'}>
# rxn00830_c {'c'} {<Node id=163929 labels={'Function'} properties={'updated_at': 1568619775853, 'created_at': 1568619775853, 'key': 'Isopentenyl-diphosphate delta-isomerase (EC 5.3.3.2)'}>, <Node id=76204 labels={'Function'} properties={'updated_at': 1563774543051, 'created_at': 1563774377084, 'key': 'Isopentenyl-diphosphate delta-isomerase, FMN-dependent (EC 5.3.3.2)'}>, <Node id=168894 labels={'Function'} properties={'updated_at': 1568619837479, 'created_at': 1568619837479, 'key': 'methylitaconate Delta-isomerase (EC 5.3.3.6)'}>}
# <Node id=90883 labels={'ModelSeedReaction'} properties={'updated_at': 1568609864824, 'equation': '(1) cpd00521[0] => (1) cpd00001[0] + (1) cpd04024[0]', 'name': '4,6-Dideoxy-4-oxo-dTDP-D-glucose 2,3-hydro-lyase (dTDP-3,4-dioxo-2,6-dideoxy-D-glucose-forming)', 'created_at': 1568609864824, 'definition': '(1) dTDP-4-oxo-6-deoxy-D-glucose[0] => (1) H2O[0] + (1) dTDP-3,4-dioxo-2,6-dideoxy-D-glucose[0]', 'id': 'rxn03807', 'key': 'rxn03807'}>
# rxn03807_c {'c'} {<Node id=164225 labels={'Function'} properties={'updated_at': 1568619779363, 'created_at': 1568619779363, 'key': 'trans-feruloyl-CoA hydratase (EC 4.2.1.101)'}>}
# <Node id=95759 labels={'ModelSeedReaction'} properties={'updated_at': 1568609929150, 'equation': '(1) cpd00005[0] + (1) cpd00067[0] + (1) cpd15352[0] => (1) cpd00006[0] + (1) cpd15353[0]', 'name': 'quinone reductase', 'created_at': 1568609929150, 'definition': '(1) NADPH[0] + (1) H+[0] + (1) 2-Demethylmenaquinone 8[0] => (1) NADP[0] + (1) 2-Demethylmenaquinol 8[0]', 'id': 'rxn08979', 'key': 'rxn08979'}>
# rxn08979_c {'c'} {<Node id=181412 labels={'FunctionComplex'} properties={'updated_at': 1568634775830, 'created_at': 1568634775830, 'key': 'cpx00309'}>}
# <Node id=95628 labels={'ModelSeedReaction'} properties={'updated_at': 1568609927367, 'equation': '(1) cpd15347[0] + (1) cpd15539[0] => (1) cpd02090[0] + (1) cpd15406[0]', 'name': 'Lysophospholipase L2 (acyltransferase, 2-acyl-glycerophosphoglycerol, n-C16:1)', 'created_at': 1568609927367, 'definition': '(1) 2-Acyl-sn-glycero-3-phosphoglycerol hexadec-9-enoyl[0] + (1) Phosphatidylglycerol dihexadec-9-enoyl[0] => (1) Glycerophosphoglycerol[0] + (1) acyl phosphatidylglycerol hexadec-9-enoyl[0]', 'id': 'rxn08835', 'key': 'rxn08835'}>
# rxn08835_c {'c'} set()
# <Node id=99550 labels={'ModelSeedReaction'} properties={'stoichiometry': '-1:cpd00001:0:0:"H2O";-1:cpd16974:0:0:"phosphatidyl-1D-myo-inositol-C160";1:cpd00067:0:0:"H+";1:cpd00867:0:0:"Inositol 1-phosphate";1:cpd15309:0:0:"1,2-Diacyl-sn-glycerol dihexadecanoyl"', 'notes': 'HB|GFP|EQP', 'code': '(1) cpd00001[0] + (1) cpd16974[0] <=> (1) cpd00867[0] + (1) cpd15309[0]', 'equation': '(1) cpd00001[0] + (1) cpd16974[0] <=> (1) cpd00067[0] + (1) cpd00867[0] + (1) cpd15309[0]', 'deltag': 10000000.0, 'is_transport': 0, 'created_at': 1568612934170, 'source': 'Orphan', 'abbreviation': 'PLCD', 'is_obsolete': 0, 'compound_ids': 'cpd00001;cpd00067;cpd00867;cpd15309;cpd16974', 'updated_at': 1568612934170, 'reversibility': '?', 'name': 'phospholipase-C', 'deltagerr': 10000000.0, 'definition': '(1) H2O[0] + (1) phosphatidyl-1D-myo-inositol-C160[0] <=> (1) H+[0] + (1) Inositol 1-phosphate[0] + (1) 1,2-Diacyl-sn-glycerol dihexadecanoyl[0]', 'id': 'rxn13518', 'key': 'rxn13518', 'status': 'OK', 'direction': '='}>
# rxn13518_c {'c'} set()
# <Node id=98822 labels={'ModelSeedReaction'} properties={'stoichiometry': '-1:cpd00067:1:0:"H+";-1:cpd11592:1:0:"gly-glu-L";1:cpd00067:0:0:"H+";1:cpd11592:0:0:"gly-glu-L"', 'notes': 'GFP|EQP', 'aliases': 'Name: gly-glu-L transport via proton symport', 'code': '(1) cpd11592[1] <=> (1) cpd11592[0]', 'equation': '(1) cpd00067[1] + (1) cpd11592[1] <=> (1) cpd00067[0] + (1) cpd11592[0]', 'deltag': 10000000.0, 'is_transport': 1, 'created_at': 1568612923545, 'source': 'Orphan', 'abbreviation': 'gly-glu-L transport via proton symport', 'is_obsolete': 0, 'compound_ids': 'cpd00067;cpd11592', 'updated_at': 1568612923545, 'reversibility': '?', 'name': 'gly-glu-L transport via proton symport', 'deltagerr': 10000000.0, 'definition': '(1) H+[1] + (1) gly-glu-L[1] <=> (1) H+[0] + (1) gly-glu-L[0]', 'id': 'rxn12600', 'key': 'rxn12600', 'direction': '=', 'status': 'OK'}>
# rxn12600_c {'e', 'c'} set()
# <Node id=97789 labels={'ModelSeedReaction'} properties={'stoichiometry': '-1:cpd00067:1:0:"H+";-1:cpd01570:1:0:"2\',3\'-Cyclic AMP";1:cpd00067:0:0:"H+";1:cpd01570:0:0:"2\',3\'-Cyclic AMP"', 'notes': 'GFC|EQC', 'aliases': "Name: 2',3'-Cyclic AMP transport in via proton symport", 'code': '(1) cpd01570[1] <=> (1) cpd01570[0]', 'equation': '(1) cpd00067[1] + (1) cpd01570[1] <=> (1) cpd00067[0] + (1) cpd01570[0]', 'deltag': 0.0, 'is_transport': 1, 'created_at': 1568612908130, 'source': 'Orphan', 'abbreviation': "2',3'-Cyclic AMP transport in via proton symport", 'is_obsolete': 0, 'compound_ids': 'cpd00067;cpd01570', 'updated_at': 1568612908130, 'reversibility': '=', 'name': "2',3'-Cyclic AMP transport in via proton symport", 'deltagerr': 5.36, 'definition': "(1) H+[1] + (1) 2',3'-Cyclic AMP[1] <=> (1) H+[0] + (1) 2',3'-Cyclic AMP[0]", 'id': 'rxn11400', 'key': 'rxn11400', 'direction': '=', 'status': 'OK'}>
# rxn11400_c {'e', 'c'} set()
# <Node id=95894 labels={'ModelSeedReaction'} properties={'updated_at': 1568609930941, 'equation': '(1) cpd00001[0] + (1) cpd15528[0] => (1) cpd00067[0] + (1) cpd01741[0] + (1) cpd15336[0]', 'name': 'Phospholipase A1 (phosphatidylethanolamine, n-C12:0) (periplasm)', 'created_at': 1568609930941, 'definition': '(1) H2O[0] + (1) phosphatidylethanolamine didodecanoyl[0] => (1) H+[0] + (1) ddca[0] + (1) 2-Acyl-sn-glycero-3-phosphoethanolamine dodecanoyl[0]', 'id': 'rxn09130', 'key': 'rxn09130'}>
# rxn09130_c {'c'} {<Node id=162678 labels={'Function'} properties={'updated_at': 1568619761489, 'created_at': 1568619761489, 'key': 'Phospholipase A1 precursor (EC 3.1.1.32, EC 3.1.1.4)'}>}
# <Node id=100023 labels={'ModelSeedReaction'} properties={'stoichiometry': '-1:cpd00001:0:0:"H2O";-1:cpd00350:0:0:"Farnesyldiphosphate";1:cpd00012:0:0:"PPi";1:cpd00067:0:0:"H+";1:cpd00829:0:0:"2-trans,6-trans-Farnesol"', 'aliases': 'AraCyc: RXN-8617|CornCyc: RXN-8617|KEGG: R08697|MetaCyc: RXN-8617|PlantCyc: RXN-8617|Name: (2E,6E)-farnesyl-diphosphate diphosphohydrolase; FPP phosphatase; farnesyl diphosphatase; trans,trans-Farnesyl-diphosphate diphosphohydrolase', 'notes': 'GFC|HB|EQC|EQU', 'code': '(1) cpd00001[0] + (1) cpd00350[0] <=> (1) cpd00012[0] + (1) cpd00829[0]', 'equation': '(1) cpd00001[0] + (1) cpd00350[0] => (1) cpd00012[0] + (1) cpd00067[0] + (1) cpd00829[0]', 'deltag': -6.21, 'is_transport': 0, 'created_at': 1568612940988, 'pathways': 'MetaCyc: Energy-Metabolism (Generation of Precursor Metabolite and Energy); HORMONE-SYN (Hormone Biosynthesis); JH-III-Biosynthesis (juvenile hormone III biosynthesis); PWY-6650 (juvenile hormone III biosynthesis II); PWY-6859 (<i>all-trans</i>-farnesol biosynthesis); SECONDARY-METABOLITE-BIOSYNTHESIS (Secondary Metabolite Biosynthesis); SESQUITERPENOID-SYN (Sesquiterpenoid Biosynthesis); Terpenoid-Biosynthesis (Terpenoid Biosynthesis)|KEGG: rn00900 (Terpenoid backbone biosynthesis); rn00909 (Sesquiterpenoid and triterpenoid biosynthesis); rn01110 (Biosynthesis of secondary metabolites)', 'ec_numbers': '3.1.7.6', 'source': 'Primary Database', 'abbreviation': 'R08697', 'is_obsolete': 0, 'compound_ids': 'cpd00001;cpd00012;cpd00067;cpd00350;cpd00829', 'updated_at': 1568612940988, 'reversibility': '>', 'name': 'trans,trans-Farnesyl-diphosphate diphosphohydrolase', 'deltagerr': 0.59, 'definition': '(1) H2O[0] + (1) Farnesyldiphosphate[0] => (1) PPi[0] + (1) H+[0] + (1) 2-trans,6-trans-Farnesol[0]', 'id': 'rxn14080', 'key': 'rxn14080', 'status': 'OK', 'direction': '>'}>
# rxn14080_c {'c'} {<Node id=167888 labels={'Function'} properties={'updated_at': 1568619824879, 'created_at': 1568619824879, 'key': 'sclareol cyclase (EC 3.1.7.4)'}>}
# <Node id=88212 labels={'ModelSeedReaction'} properties={'updated_at': 1568609828868, 'equation': '(1) cpd00003[0] + (1) cpd00190[0] <=> (1) cpd00004[0] + (1) cpd00067[0] + (1) cpd00170[0]', 'name': 'beta-D-Glucose:NAD+ 1-oxoreductase', 'created_at': 1568609828868, 'definition': '(1) NAD[0] + (1) beta-D-Glucose[0] <=> (1) NADH[0] + (1) H+[0] + (1) Gluconolactone[0]', 'id': 'rxn01108', 'key': 'rxn01108'}>
# rxn01108_c {'c'} {<Node id=79274 labels={'Function'} properties={'updated_at': 1563774554212, 'created_at': 1563774439663, 'key': 'Glucose 1-dehydrogenase (EC 1.1.1.47)'}>, <Node id=172046 labels={'Function'} properties={'updated_at': 1568619877839, 'created_at': 1568619877839, 'key': 'glucose 1-dehydrogenase (EC 1.1.1.47)'}>}
# <Node id=92268 labels={'ModelSeedReaction'} properties={'updated_at': 1568609883429, 'equation': '(1) cpd00001[0] + (1) cpd00002[0] + (1) cpd00060[1] => (1) cpd00008[0] + (1) cpd00009[0] + (1) cpd00060[0] + (1) cpd00067[0]', 'name': 'nonpolar-amino-acid-transporting ATPase', 'created_at': 1568609883429, 'definition': '(1) H2O[0] + (1) ATP[0] + (1) L-Methionine[1] => (1) ADP[0] + (1) Phosphate[0] + (1) L-Methionine[0] + (1) H+[0]', 'id': 'rxn05219', 'key': 'rxn05219'}>
# rxn05219_c {'e', 'c'} {<Node id=177372 labels={'FunctionComplex'} properties={'updated_at': 1568634675795, 'created_at': 1568634675795, 'key': 'cpx00126'}>}
# <Node id=96705 labels={'ModelSeedReaction'} properties={'updated_at': 1568609942311, 'equation': '(0.5) cpd00007[0] + (2.5) cpd00067[0] + (1) cpd15561[0] => (1) cpd00001[0] + (2.5) cpd00067[1] + (1) cpd15560[0]', 'name': 'cytochrome oxidase bo3 (ubiquinol-8: 2.5 protons)', 'created_at': 1568609942311, 'definition': '(0.5) O2[0] + (2.5) H+[0] + (1) Ubiquinol-8[0] => (1) H2O[0] + (2.5) H+[1] + (1) Ubiquinone-8[0]', 'id': 'rxn10113', 'key': 'rxn10113'}>
# rxn10113_c {'e', 'c'} {<Node id=178432 labels={'FunctionComplex'} properties={'updated_at': 1568634701794, 'created_at': 1568634701794, 'key': 'cpx00746'}>, <Node id=178434 labels={'FunctionComplex'} properties={'updated_at': 1568634701883, 'created_at': 1568634701883, 'key': 'cpx00744'}>, <Node id=178435 labels={'FunctionComplex'} properties={'updated_at': 1568634701941, 'created_at': 1568634701941, 'key': 'cpx00745'}>, <Node id=78198 labels={'Function'} properties={'updated_at': 1563774473176, 'created_at': 1563774417616, 'key': 'Cytochrome O ubiquinol oxidase subunit II (EC 1.10.3.-)'}>, <Node id=78199 labels={'Function'} properties={'updated_at': 1563774473194, 'created_at': 1563774417649, 'key': 'Cytochrome O ubiquinol oxidase subunit I (EC 1.10.3.-)'}>, <Node id=78200 labels={'Function'} properties={'updated_at': 1563774473211, 'created_at': 1563774417679, 'key': 'Cytochrome O ubiquinol oxidase subunit III (EC 1.10.3.-)'}>, <Node id=78201 labels={'Function'} properties={'updated_at': 1563774473229, 'created_at': 1563774417718, 'key': 'Cytochrome O ubiquinol oxidase subunit IV (EC 1.10.3.-)'}>, <Node id=178429 labels={'FunctionComplex'} properties={'updated_at': 1568634701717, 'created_at': 1568634701717, 'key': 'cpx00743'}>}
# <Node id=96881 labels={'ModelSeedReaction'} properties={'updated_at': 1568609944625, 'equation': '(24) cpd00402[0] + (1) cpd15731[0] <=> (24) cpd00046[0] + (24) cpd00067[0] + (1) cpd15749[0]', 'name': 'isoheptadecanoyl-lipoteichoic acid synthesis (n=24), linked, unsubstituted', 'created_at': 1568609944625, 'definition': '(24) CDPglycerol[0] + (1) Diglucosyl-1,2 diisoheptadecanoylglycerol[0] <=> (24) CMP[0] + (24) H+[0] + (1) Isoheptadecanoyllipoteichoic acid (n=24), linked, unsubstituted[0]', 'id': 'rxn10292', 'key': 'rxn10292'}>
# rxn10292_c {'c'} {<Node id=163019 labels={'Function'} properties={'updated_at': 1568619765461, 'created_at': 1568619765461, 'key': 'CDP-glycerol:poly(glycerophosphate) glycerophosphotransferase (EC 2.7.8.12)'}>}
# <Node id=88509 labels={'ModelSeedReaction'} properties={'updated_at': 1568609832853, 'equation': '(1) cpd00043[0] + (1) cpd00267[0] <=> (1) cpd00014[0] + (1) cpd01205[0]', 'name': 'UDP-galactose:sphingosine 1-beta-galactosyltransferase', 'created_at': 1568609832853, 'definition': '(1) UDP-galactose[0] + (1) Sphingoid[0] <=> (1) UDP[0] + (1) Psychosine[0]', 'id': 'rxn01413', 'key': 'rxn01413'}>
# rxn01413_c {'c'} {<Node id=173897 labels={'Function'} properties={'updated_at': 1568619900917, 'created_at': 1568619900917, 'key': 'sphingosine beta-galactosyltransferase (EC 2.4.1.23)'}>}
# <Node id=87986 labels={'ModelSeedReaction'} properties={'updated_at': 1568609825912, 'equation': '(1) cpd00003[0] + (1) cpd00121[0] <=> (1) cpd00004[0] + (1) cpd00067[0] + (1) cpd00524[0]', 'name': 'myo-Inositol:NAD+ 2-oxidoreductase', 'created_at': 1568609825912, 'definition': '(1) NAD[0] + (1) L-Inositol[0] <=> (1) NADH[0] + (1) H+[0] + (1) 2-Inosose[0]', 'id': 'rxn00879', 'key': 'rxn00879'}>
# rxn00879_c {'c'} {<Node id=81028 labels={'Function'} properties={'updated_at': 1563774479648, 'created_at': 1563774479648, 'key': 'Myo-inositol 2-dehydrogenase (EC 1.1.1.18)'}>, <Node id=166135 labels={'Function'} properties={'updated_at': 1568619802091, 'created_at': 1568619802091, 'key': 'inositol 2-dehydrogenase (EC 1.1.1.18)'}>}
# <Node id=95981 labels={'ModelSeedReaction'} properties={'updated_at': 1568609932129, 'equation': '(4) cpd00067[0] + (1) cpd02113[0] + (1) cpd15492[0] <= (1) cpd00297[0] + (1) cpd15489[0]', 'name': 'rhamnosyltransferase I (LPS core biosynthesis)', 'created_at': 1568609932129, 'definition': '(4) H+[0] + (1) dTDP-rhamnose[0] + (1) kdo-phospho-heptosyl-phospho-heptosyl-heptosyl-kdo2-lipidA[0] <= (1) dTDP[0] + (1) inner core oligosaccharide lipid A[0]', 'id': 'rxn09225', 'key': 'rxn09225'}>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-204-421915e38f01> in <module>()
#      23                     or_rule.add(function_complexes[complex_id])
#      24                 else:
# ---> 25                     or_rule.add(list(cpx_to_function_uids[complex_id])[0])
#      26
#      27         print(rxn['id'], rxn_compartments, or_rule)
#
# IndexError: list index out of range

# %%
def add_template_reaction_annotation(annotation_api, template, rxn, cmps, function_rule, props):
    
    trxn_ann_node_id = rxn.get('key') + '_' + '_'.join(sorted(list(cmps)))
    
    trxn_ann_node = annotation_api.get_node('TemplateReactionAnnotation', trxn_ann_node_id)
    
    if trxn_ann_node == None:
        trxn_ann_node = annotation_api.add_node('TemplateReactionAnnotation', trxn_ann_node_id, props)
        for rule in function_rule:
            annotation_api.link_nodes(trxn_ann_node, rule, 'has_function')
    
        annotation_api.link_nodes(template, trxn_ann_node, 'has_annotation_rule')
        annotation_api.link_nodes(trxn_ann_node, rxn, 'has_reaction')
    
    return trxn_ann_node
add_template_reaction_annotation(annotation_api, template_node, rxn_node, rxn_compartments, or_rule)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-206-6c9fc420d0c3> in <module>()
#      14
#      15     return trxn_ann_node
# ---> 16 add_template_reaction_annotation(annotation_api, template_node, rxn_node, rxn_compartments, or_rule)
#
# TypeError: add_template_reaction_annotation() missing 1 required positional argument: 'props'

# %%
def get_relationship(tx, label, key, relationship_type):
    result = tx.run("MATCH (n1:ModelSeedReaction {key:$key})-[r]-(n2) RETURN r", key = key)
    return list(result.records())

# %%
#rxn_doc = annotation_api.get_node('ModelSeedReaction', seed_id)
def get_r_nodes(annotation_api, label, key, relationship_type = None):
    result = None
    with annotation_api.driver.session() as session:
        query = session.read_transaction(get_relationship, label, key, relationship_type)
        if len(query) > 0:
            print(query[0].data())
            #result = query[0].data()['n']
    return result
get_r_nodes(annotation_api, 'ModelSeedReaction', 'rxn00004')
# Out:
# {'r': <Relationship id=99688 nodes=(<Node id=87034 labels=set() properties={}>, <Node id=133792 labels=set() properties={}>) type='has_crossreference_to' properties={}>}

# %%
for r in template_node.graph.relationships:
    print(r)

# %%
def get_ko_by_seed_id(annotation_api, seed_id):
    rxn_doc = annotation_api.get_node('ModelSeedReaction', seed_id)
    print(rxn_doc)
    if not rxn_doc == None:
        for r in rxn_doc.graph.relationships:
            print(r)
        if 'kegg_kos' in rxn_doc:
            return set(rxn_doc['kegg_kos'])
        else:
            return set()
    return None
get_ko_by_seed_id(annotation_api, 'rxn00004')
# Out:
# <Node id=87034 labels={'ModelSeedReaction'} properties={'updated_at': 1568609814074, 'equation': '(1) cpd02570[0] <=> (2) cpd00020[0]', 'name': '4-hydroxy-4-methyl-2-oxoglutarate pyruvate-lyase (pyruvate-forming)', 'created_at': 1568609814074, 'definition': '(1) Parapyruvate[0] <=> (2) Pyruvate[0]', 'id': 'rxn00004', 'key': 'rxn00004'}>
# set()

# %%
def get_reaction_annotation_data(rxn_id):
    kos = annotation_api.get_ko_by_seed_id(rxn_id)
    function_data = {}
    for ko in kos:
        #print(ko)
        functions, functions_data, metadata = get_functional_roles2(ko, annotation_api)
        print(ko, metadata)
        for f in functions:
            function = functions_data[f]['value']
            if not function in function_data:
                function_data[function] = {
                    'id' : f,
                    'hits' : []
                }
            function_data[function]['hits'].append({
                'score' : len(functions[f]),
                'source' : ['KEGG', ko]
            })
    for template_doc in annotation_api.collection_templates.find():
        if rxn_id in template_doc['reactions']:
            template_id = template_doc['_id']
            template_reaction_doc = template_doc['reactions'][rxn_id]
            for and_rule in template_reaction_doc['functions']:
                for function_id in and_rule:
                    function_doc = annotation_api.collection_functions.find_one({'_id' : function_id})
                    function = function_doc['value']
                    if not function in function_data:
                        function_data[function] = {
                            'id' : function_id,
                            'hits' : []
                        }
                    function_data[function]['hits'].append({
                        'score' : 0,
                        'source' : ['template', template_id]
                    })
                    #print(template_id, function_doc['value'])
        
    for function in function_data:
        function_id = function_data[function]['id']
        #print(function_id)
        function_doc = annotation_api.collection_functions.find_one({'_id' : function_id})
        function_metadata = annotation_api.collection_functions_data.find_one({'_id' : function_id})
        
        subsystem_tags = {}
        if 'subsystem' in function_doc:
            for subsystem_tag in function_doc['subsystem']:
                subsystem_tags[subsystem_tag] = [function_doc['subsystem'][subsystem_tag]]
                if 'subsystem_class' in function_doc and subsystem_tag in function_doc['subsystem_class']:
                    subsystem_tags[subsystem_tag].append(function_doc['subsystem_class'][subsystem_tag])
        #print(subsystem_tags)
        
        
        source_tags = {}
        if not function_metadata == None:
            sources = function_metadata['sources']
            for s in sources:
                source_tags[s] = [len(sources[s]['genomes']), len(sources[s]['genes']), sources[s]['genes'][:10]]
            #print(source_tags)
        function_data[function]['sources'] = source_tags
        function_data[function]['subsystems'] = subsystem_tags
    return function_data
